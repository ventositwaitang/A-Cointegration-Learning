# %%
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import scipy.optimize as spop
import matplotlib.pyplot as plt

# %%
#specifying rolling window length
window = 21
#specifying maximum KPSS statistic (critical value); trade when KPSS < KPSS_max
KPSS_max = 0.463 # 95% = 0.463, 99% = 0.739 for unbiased(const); 95% = 0.146, 99% = 0.216 for biased(const+trend);tune for more conservative / lenient
#specifying the KPSS test (one-parameter unbiased or two-parameter) (unbiased algo, setting εt as 0, vary one para (const)/ non-unbiased algo, vary both para (const + trend)
unbiased = 1
#specifying whether to perform beta-loading or not
beta_loading = 1 # 0 equal weighted long/short pos; 1 adjust size position for long/short pair according to stockβ (ratio of $stock change to $market change)
#strategy parameters - trading fee, optimal entry (divergence), and stop-loss
fee = 0.0001
entry = 0.02
stop_loss = -0.05
#initially start in cash
signal = 0
current_return = 0
position0 = 0
position1 = 0
#specifying the sample
start = '2019-09-28'
end = '2021-09-28'
#specifying the pair
tickers = ['XOM', 'CVX'] ###
#specifying the market index
market = '^GSPC'

# %%
#initialising arrays
gross_returns = np.array([])
net_returns = np.array([])
market_returns = np.array([])
signals = np.array([])
KPSS_stats = np.array([])
raw_data = pd.DataFrame()

DF_stats = np.array([])
stock1 = tickers[0]
stock2 = tickers[1]

traded_dates = np.array([])

# %%
#downloading price data for stocks and the market index
for ticker in tickers:
    raw_data[ticker] = yf.download(ticker, start, end)['Close']
raw_data['market'] = yf.download(market, start, end)['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(raw_data[stock2],label=stock2)
plt.plot(raw_data[stock1],label=stock1)
plt.legend()

# %%
raw_data.corr()
# Out:
#              XOM       CVX    market
# XOM     1.000000  0.970498  0.232357
# CVX     0.970498  1.000000  0.211724
# market  0.232357  0.211724  1.000000

# %%
raw_data
# Out:
#                   XOM         CVX       market
# Date
# 2019-09-30  70.610001  118.599998  2976.739990
# 2019-10-01  68.949997  116.010002  2940.250000
# 2019-10-02  67.150002  112.290001  2887.610107
# 2019-10-03  67.980003  113.150002  2910.629883
# 2019-10-04  68.970001  113.849998  2952.010010
# ...               ...         ...          ...
# 2021-09-21  53.639999   94.849998  4354.189941
# 2021-09-22  55.209999   97.639999  4395.640137
# 2021-09-23  57.080002  100.059998  4448.979980
# 2021-09-24  57.590000  100.599998  4455.479980
# 2021-09-27  59.299999  102.970001  4443.109863
#
# [503 rows x 3 columns]

# %% [markdown]
# ## Table of KPSS critical values (Kwiatkowski, Phillips, Schmidt, and Shin)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let residual $S_t = ∑𝜀_t = Y - \hat{Y} = Y - (𝛼 + 𝛽X)$
#
# The drift 𝛼 (constant) and trend 𝛽 (slope) are  fitted by OLS
#
# > $H_0$ : The time seires $y_t$ is trend stationary
#
# > $H_1$ : The time seires $y_t$ has a unit root (is non-stationary)
#
# KPSS-Statistics:
#
# $KPSS = \frac{\sum_{i=1}^{N}S_t^2}{N^2𝜎^2}$
#
# We trade the pair when KPSS-stat < tolerance (set as KPSS_max = 0.463).(i.e. the pair is cointegrated)
#
# Profitable entry is when pair diverge enough from dynamic equilibrium (fair value),

# %% [markdown]
# > The tradition pair trade strategy is used in this learning (divergen entry→ convergence stop_loss) (i.e. when return growth of short position is stronger than long position (-ve return> +ve return), the pair position have to close)
#
# > Another strategy (convergen entery→ divergen stop_loss) would be considered and tried afterward (e.g. 2330--FITX; XOM--QG if high correlation)

# %% [markdown]
# #### Without $β$ loading position

# %%
#specifying rolling window length
window = 21
#specifying maximum KPSS statistic (95% critical value)
KPSS_max = 0.463 # tune for more conservative / lenient
#specifying the KPSS test (one-parameter unbiased or two-parameter) (unbiased algo, setting εt as 0, vary one para/ non-unbiased algo, vary both para: const  &slope
unbiased = 1
#specifying whether to perform beta-loading or not
beta_loading = 0
#strategy parameters - trading fee, optimal entry (divergence), and stop-loss
fee = 0.0001
entry = 0.02
stop_loss = -0.05
#initially start in cash
signal = 0
current_return = 0
position0 = 0
position1 = 0
#specifying the sample
start = '2019-09-28'
end = '2021-09-28'
#specifying the pair
tickers = ['XOM', 'CVX']
stock1 = tickers[0]
stock2 = tickers[1]
#specifying the market index
market = '^GSPC'
#initialising arrays
gross_returns = np.array([])
net_returns = np.array([])
market_returns = np.array([])
signals = np.array([])
KPSS_stats = np.array([])
raw_data = pd.DataFrame()
#downloading price data for stocks and the market index
for ticker in tickers:
    raw_data[ticker] = yf.download(ticker, start, end)['Close']
raw_data['market'] = yf.download(market, start, end)['Close']
#moving in a loop through the sample
for t in range(window, len(raw_data)-1):
    old_signal = signal
    old_position0 = position0
    old_position1 = position1
    #specifying the subsample
    data = raw_data[t-window:t]
    #stock 2 = a + b*stock 1
    #OLS parameters as starting values
    reg = sm.OLS(np.array(data[tickers[1]]), sm.add_constant(np.array(data[tickers[0]])))
    res = reg.fit()
    a0 = res.params[0]
    b0 = res.params[1]
    if unbiased == 1:
        #defining the KPSS function (unbiased one-parameter forecast)
        def KPSS(b):
            a = np.average(data[tickers[1]] - b*data[tickers[0]])
            resid = np.array(data[tickers[1]] - (a + b*data[tickers[0]]))
            cum_resid = np.cumsum(resid)
            st_error = (np.sum(resid**2)/(len(resid)-2))**(1/2)
            KPSS = np.sum(cum_resid**2)/(len(resid)**2*st_error**2)
            return KPSS
        #minimising the KPSS function (maximising the stationarity)
        res = spop.minimize(KPSS, b0, method='Nelder-Mead')
        KPSS_opt = res.fun
        #retrieving optimal parameters
        b_opt = float(res.x)
        a_opt = np.average(data[tickers[1]] - b_opt*data[tickers[0]])
    else:
        #defining the KPSS function (two-parameter)
        def KPSS2(kpss_params):
            a = kpss_params[0]
            b = kpss_params[1]
            resid = np.array(data[tickers[1]] - (a + b*data[tickers[0]]))
            cum_resid = np.cumsum(resid)
            st_error = (np.sum(resid**2)/(len(resid)-2))**(1/2)
            KPSS = np.sum(cum_resid**2)/(len(resid)**2*st_error**2)
            return KPSS
        #minimising the KPSS function (maximising the stationarity)
        res = spop.minimize(KPSS2, [a0, b0], method='Nelder-Mead')
        #retrieving optimal parameters
        KPSS_opt = res.fun
        a_opt = res.x[0]
        b_opt = res.x[1]
    #simulate trading
    #first check whether stop-loss is violated
    if current_return < stop_loss:
        signal = 0
        print('stop-loss triggered')
    #if we are already in position, check whether the equilibrium is restored, continue in position if not
    elif np.sign(raw_data[tickers[1]][t] - (a_opt + b_opt*raw_data[tickers[0]][t])) == old_signal:
        singal = old_signal
    else:
        #only trade if the pair is cointegrated
        if KPSS_opt > KPSS_max:
            signal = 0
        #only trade if there are large enough profit opportunities (optimal entry)
        elif abs(raw_data[tickers[1]][t]/(a_opt + b_opt*raw_data[tickers[0]][t])-1) < entry:
            signal = 0
        else:
            signal = np.sign(raw_data[tickers[1]][t] - (a_opt + b_opt*raw_data[tickers[0]][t]))
    #calculate strategy returns with beta loading
    if beta_loading == 1:
        rets0 = np.array(raw_data[tickers[0]][t-window:t-1])/np.array(raw_data[tickers[0]][t-window+1:t]) - 1
        rets1 = np.array(raw_data[tickers[1]][t-window:t-1])/np.array(raw_data[tickers[1]][t-window+1:t]) - 1
        rets_mkt = np.array(raw_data['market'][t-window:t-1])/np.array(raw_data['market'][t-window+1:t]) - 1
        reg = sm.OLS(rets0, sm.add_constant(rets_mkt))
        res = reg.fit()
        beta0 = res.params[1] #
        reg = sm.OLS(rets1, sm.add_constant(rets_mkt))
        res = reg.fit()
        beta1 = res.params[1] #
        position0 = beta1*signal
        position1 = -beta0*signal
    #calculate strategy returns without beta loading
    else:
        position0 = signal
        position1 = -signal

    print(f'position_{stock1}:',position0)
    print('times_ret1：',(raw_data[stock1][t+1]/raw_data[stock1][t] - 1))
    print(f'position_{stock2}:',position1)
    print('times_ret2：',(raw_data[stock2][t+1]/raw_data[stock2][t] - 1))
    print("===========")
    #calculating returns
    gross = position0*(raw_data[tickers[0]][t+1]/raw_data[tickers[0]][t] - 1) + position1*(raw_data[tickers[1]][t+1]/raw_data[tickers[1]][t] - 1)
    net = gross - fee*(abs(position0 - old_position0) + abs(position1 - old_position1))
    market = raw_data['market'][t+1]/raw_data['market'][t] - 1

    if signal == old_signal:
        current_return = (1+current_return)*(1+gross)-1
    else:
        current_return = gross
    #populating arrays
    KPSS_stats = np.append(KPSS_stats, KPSS_opt)
    signals = np.append(signals, signal)
    gross_returns = np.append(gross_returns, gross)
    net_returns = np.append(net_returns, net)
    market_returns = np.append(market_returns, market)

    #interface: reporting daily positions and realised returns
    print('day '+str(raw_data.index[t]))
    print('')
    print('old_signal:',old_position0, '→signal:',position0)
    if position0 == old_position0: #signal == 0: #position0 == 0:
        print('no trading')
    elif  position0 > old_position0: #signal == 1: # position0 > 0:
        print(f'buy {stock1}:',(position0 - old_position0),'*',raw_data[stock1][t],f' and sell {stock2}:',abs(position1 - old_position1),'*',raw_data[stock2][t])
        print('long position on '+stock1+' and short position on '+stock2)
        traded_date = raw_data.index[t]
    else:
        print(f'buy {stock2}:',(position1 - old_position1),'*',raw_data[stock1][t],f' and sell {stock1}:',abs(position0 - old_position0),'*',raw_data[stock1][t])
        print('long position on '+stock2+' and short position on '+stock1)
        traded_date = raw_data.index[t]

    traded_dates = np.append(traded_dates, traded_date)
    print('gross daily return: '+str(round(gross*100,2))+'%')
    print('net daily return: '+str(round(net*100,2))+'%')
    print('cumulative net return so far: '+str(round(np.prod(1+net)*100-100,2))+'%')
    print('————————next day————————')

#building the output dataframe
output0 = pd.DataFrame()
output0['KPSS'] = KPSS_stats
output0['signal'] = signals
output0['gross'] = gross_returns
output0['net'] = net_returns
output0['market'] = market_returns
#visualising the results
plt.plot(np.append(1,np.cumprod(1+gross_returns)))
plt.plot(np.append(1,np.cumprod(1+net_returns)))
plt.plot(np.append(1,np.cumprod(1+market_returns)))
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# times_ret2： 0.046088953550541545
# ===========
# day 2020-03-27 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 36.95000076293945  and sell XOM: 1.0 * 36.95000076293945
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.012533365885416758
# position_CVX: 0
# times_ret2： 0.0070882857242835495
# ===========
# day 2020-03-30 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.011588159790901997
# position_CVX: 0
# times_ret2： -0.0538228205238086
# ===========
# day 2020-03-31 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.07647223127982739
# position_CVX: 1.0
# times_ret2： 0.11026845766041982
# ===========
# day 2020-04-01 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 37.529998779296875  and sell XOM: 1.0 * 37.529998779296875
# long position on CVX and short position on XOM
# gross daily return: 3.38%
# net daily return: 3.36%
# cumulative net return so far: 3.36%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.02945550486288906
# position_CVX: 1.0
# times_ret2： -0.013268550969355086
# ===========
# day 2020-04-02 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 1.62%
# net daily return: 1.62%
# cumulative net return so far: 1.62%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.03213471475773222
# position_CVX: 1.0
# times_ret2： 0.07029688105966003
# ===========
# day 2020-04-03 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 3.82%
# net daily return: 3.82%
# cumulative net return so far: 3.82%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.019026450075068535
# position_CVX: 0
# times_ret2： 0.006592844673726006
# ===========
# day 2020-04-06 00:00:00
#
# old_signal: -1.0 →signal: 0
# buy XOM: 1.0 * 40.470001220703125  and sell CVX: 1.0 * 80.38999938964844
# long position on XOM and short position on CVX
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.06328798955934789
# position_CVX: 0
# times_ret2： 0.06253096023833282
# ===========
# day 2020-04-07 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.016419553729991154
# position_CVX: 0
# times_ret2： -0.019423188336095465
# ===========
# day 2020-04-08 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.008578778980266821
# position_CVX: -1.0
# times_ret2： 0.007116666123713644
# ===========
# day 2020-04-09 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 43.130001068115234  and sell CVX: 1.0 * 84.30999755859375
# long position on XOM and short position on CVX
# gross daily return: -1.57%
# net daily return: -1.59%
# cumulative net return so far: -1.59%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.007717446896887248
# position_CVX: -1.0
# times_ret2： -0.003533188538674903
# ===========
# day 2020-04-13 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.42%
# net daily return: -0.42%
# cumulative net return so far: -0.42%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.045958066201135184
# position_CVX: -1.0
# times_ret2： -0.025056172217101547
# ===========
# day 2020-04-14 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -2.09%
# net daily return: -2.09%
# cumulative net return so far: -2.09%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.03285568259381322
# position_CVX: -1.0
# times_ret2： -0.03030670462773799
# ===========
# day 2020-04-15 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -0.25%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.10395911969847238
# position_CVX: -1.0
# times_ret2： 0.08976122636487616
# ===========
# day 2020-04-16 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.42%
# net daily return: 1.42%
# cumulative net return so far: 1.42%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0472003900488126
# position_CVX: 0
# times_ret2： -0.041298595270633065
# ===========
# day 2020-04-17 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 43.220001220703125  and sell XOM: 1.0 * 43.220001220703125
# long position on CVX and short position on XOM
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.00534242882643865
# position_CVX: -1.0
# times_ret2： -0.023094415606361607
# ===========
# day 2020-04-20 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 41.18000030517578  and sell CVX: 1.0 * 83.56999969482422
# long position on XOM and short position on CVX
# gross daily return: 1.78%
# net daily return: 1.76%
# cumulative net return so far: 1.76%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.02856450219224027
# position_CVX: -1.0
# times_ret2： 0.034296950914882496
# ===========
# day 2020-04-21 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.57%
# net daily return: -0.57%
# cumulative net return so far: -0.57%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.031331584651281164
# position_CVX: 0
# times_ret2： 0.02794884583274615
# ===========
# day 2020-04-22 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 42.130001068115234  and sell XOM: 1.0 * 42.130001068115234
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.006444160515083341
# position_CVX: 1.0
# times_ret2： 0.0024193442060991277
# ===========
# day 2020-04-23 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 43.45000076293945  and sell XOM: 1.0 * 43.45000076293945
# long position on CVX and short position on XOM
# gross daily return: -0.4%
# net daily return: -0.42%
# cumulative net return so far: -0.42%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.004802174403633952
# position_CVX: 1.0
# times_ret2： 0.031030880151167395
# ===========
# day 2020-04-24 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 2.62%
# net daily return: 2.62%
# cumulative net return so far: 2.62%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.023441115752972586
# position_CVX: 1.0
# times_ret2： 0.0022294569131406927
# ===========
# day 2020-04-27 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -2.12%
# net daily return: -2.12%
# cumulative net return so far: -2.12%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.055370197824748946
# position_CVX: 1.0
# times_ret2： 0.05238570673596343
# ===========
# day 2020-04-28 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.3%
# net daily return: -0.3%
# cumulative net return so far: -0.3%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.02085962669336472
# position_CVX: 1.0
# times_ret2： -0.0276897344169299
# ===========
# day 2020-04-29 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.68%
# net daily return: -0.68%
# cumulative net return so far: -0.68%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.07165917244631181
# position_CVX: 1.0
# times_ret2： -0.02782606041949731
# ===========
# day 2020-04-30 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 4.38%
# net daily return: 4.38%
# cumulative net return so far: 4.38%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.04033383641828037
# position_CVX: -1.0
# times_ret2： 0.022361358960273137
# ===========
# day 2020-05-01 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 43.13999938964844  and sell CVX: 2.0 * 89.44000244140625
# long position on XOM and short position on CVX
# gross daily return: 1.8%
# net daily return: 1.76%
# cumulative net return so far: 1.76%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.001114064970378692
# position_CVX: -1.0
# times_ret2： 0.015857359028083273
# ===========
# day 2020-05-04 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -1.7%
# net daily return: -1.7%
# cumulative net return so far: -1.7%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.018737455237086476
# position_CVX: -1.0
# times_ret2： -0.030573757740890994
# ===========
# day 2020-05-05 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.18%
# net daily return: 1.18%
# cumulative net return so far: 1.18%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.005683109580838508
# position_CVX: -1.0
# times_ret2： 0.028761757358319873
# ===========
# day 2020-05-06 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -2.31%
# net daily return: -2.31%
# cumulative net return so far: -2.31%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.04385168519677629
# position_CVX: -1.0
# times_ret2： 0.03054837920660547
# ===========
# day 2020-05-07 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.33%
# net daily return: 1.33%
# cumulative net return so far: 1.33%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.009527904369885154
# position_CVX: -1.0
# times_ret2： -0.021996422407772
# ===========
# day 2020-05-08 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.25%
# net daily return: 1.25%
# cumulative net return so far: 1.25%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.03541763636061879
# position_CVX: 0
# times_ret2： -0.02431192251993408
# ===========
# day 2020-05-11 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 45.7400016784668  and sell XOM: 1.0 * 45.7400016784668
# long position on CVX and short position on XOM
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.04963732274994026
# position_CVX: 0
# times_ret2： -0.026344693370776273
# ===========
# day 2020-05-12 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.008824205322962797
# position_CVX: -1.0
# times_ret2： 0.015219911499020355
# ===========
# day 2020-05-13 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 41.93000030517578  and sell CVX: 1.0 * 88.69999694824219
# long position on XOM and short position on CVX
# gross daily return: -0.64%
# net daily return: -0.66%
# cumulative net return so far: -0.66%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.007092180673083925
# position_CVX: -1.0
# times_ret2： -0.009883390999297248
# ===========
# day 2020-05-14 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: 0.28%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.07952381315685453
# position_CVX: -1.0
# times_ret2： 0.0380215259130714
# ===========
# day 2020-05-15 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 4.15%
# net daily return: 4.15%
# cumulative net return so far: 4.15%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.030877845636685497
# position_CVX: 1.0
# times_ret2： -0.0316585651924528
# ===========
# day 2020-05-18 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 45.34000015258789  and sell XOM: 2.0 * 45.34000015258789
# long position on CVX and short position on XOM
# gross daily return: -0.08%
# net daily return: -0.12%
# cumulative net return so far: -0.12%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.032544386660643854
# position_CVX: 1.0
# times_ret2： 0.03771476400168794
# ===========
# day 2020-05-19 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.52%
# net daily return: 0.52%
# cumulative net return so far: 0.52%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.01785315357423356
# position_CVX: 1.0
# times_ret2： -0.01032257080078125
# ===========
# day 2020-05-20 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.75%
# net daily return: 0.75%
# cumulative net return so far: 0.75%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.0008976009783978611
# position_CVX: -1.0
# times_ret2： -0.019122143836632133
# ===========
# day 2020-05-21 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 44.560001373291016  and sell CVX: 2.0 * 92.04000091552734
# long position on XOM and short position on CVX
# gross daily return: 2.0%
# net daily return: 1.96%
# cumulative net return so far: 1.96%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.029372229105593783
# position_CVX: 0
# times_ret2： 0.03345153204802087
# ===========
# day 2020-05-22 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 44.599998474121094  and sell XOM: 1.0 * 44.599998474121094
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.007188016383173457
# position_CVX: -1.0
# times_ret2： 0.006430851602311716
# ===========
# day 2020-05-26 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 45.90999984741211  and sell CVX: 1.0 * 93.30000305175781
# long position on XOM and short position on CVX
# gross daily return: 0.08%
# net daily return: 0.06%
# cumulative net return so far: 0.06%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.025951572650964483
# position_CVX: -1.0
# times_ret2： -0.032268357082633314
# ===========
# day 2020-05-27 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.63%
# net daily return: 0.63%
# cumulative net return so far: 0.63%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.009547075853356457
# position_CVX: 0
# times_ret2： 0.009133863503612227
# ===========
# day 2020-05-28 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 45.040000915527344  and sell XOM: 1.0 * 45.040000915527344
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.017813889088372115
# position_CVX: 0
# times_ret2： 0.011886630355073757
# ===========
# day 2020-05-29 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.022255890690621838
# position_CVX: 0
# times_ret2： 0.02047636067606673
# ===========
# day 2020-06-01 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.040794763245671106
# position_CVX: 0
# times_ret2： 0.026296312172030323
# ===========
# day 2020-06-02 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.002843281875981929
# position_CVX: -1.0
# times_ret2： -0.00926118052122471
# ===========
# day 2020-06-03 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 49.2400016784668  and sell CVX: 1.0 * 97.18000030517578
# long position on XOM and short position on CVX
# gross daily return: 0.64%
# net daily return: 0.62%
# cumulative net return so far: 0.62%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.08105913402484766
# position_CVX: -1.0
# times_ret2： 0.047050257963556996
# ===========
# day 2020-06-04 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 3.4%
# net daily return: 3.4%
# cumulative net return so far: 3.4%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.03127354540596339
# position_CVX: -1.0
# times_ret2： 0.024104755123750543
# ===========
# day 2020-06-05 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.72%
# net daily return: 0.72%
# cumulative net return so far: 0.72%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.022287197356499866
# position_CVX: -1.0
# times_ret2： -0.016563339014488254
# ===========
# day 2020-06-08 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.57%
# net daily return: -0.57%
# cumulative net return so far: -0.57%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.053624792737991145
# position_CVX: -1.0
# times_ret2： -0.03890472762467556
# ===========
# day 2020-06-09 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -1.47%
# net daily return: -1.47%
# cumulative net return so far: -1.47%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.08825273615084184
# position_CVX: 0
# times_ret2： -0.08413608250066495
# ===========
# day 2020-06-10 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 50.650001525878906  and sell XOM: 1.0 * 50.650001525878906
# long position on CVX and short position on XOM
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.02143780548348273
# position_CVX: 1.0
# times_ret2： 0.03379206165663806
# ===========
# day 2020-06-11 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 46.18000030517578  and sell XOM: 1.0 * 46.18000030517578
# long position on CVX and short position on XOM
# gross daily return: 1.24%
# net daily return: 1.22%
# cumulative net return so far: 1.22%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0006359716018947692
# position_CVX: 1.0
# times_ret2： -0.012555428513671085
# ===========
# day 2020-06-12 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.19%
# net daily return: -1.19%
# cumulative net return so far: -1.19%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.022486240708857297
# position_CVX: 1.0
# times_ret2： 0.03069160713946717
# ===========
# day 2020-06-15 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.82%
# net daily return: 0.82%
# cumulative net return so far: 0.82%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.032572607260856645
# position_CVX: 1.0
# times_ret2： -0.026480887972932354
# ===========
# day 2020-06-16 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.61%
# net daily return: 0.61%
# cumulative net return so far: 0.61%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.006219109890357011
# position_CVX: 1.0
# times_ret2： 0.004369691084534999
# ===========
# day 2020-06-17 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: -0.18%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.020034072109813894
# position_CVX: 1.0
# times_ret2： -0.014248478934108744
# ===========
# day 2020-06-18 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.58%
# net daily return: 0.58%
# cumulative net return so far: 0.58%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.009569348218562146
# position_CVX: 1.0
# times_ret2： 0.01059250925263
# ===========
# day 2020-06-19 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.1%
# net daily return: 0.1%
# cumulative net return so far: 0.1%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.006031938928025671
# position_CVX: 1.0
# times_ret2： -0.0016376668029445263
# ===========
# day 2020-06-22 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.77%
# net daily return: -0.77%
# cumulative net return so far: -0.77%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.04710922327618772
# position_CVX: 1.0
# times_ret2： -0.04155733760170022
# ===========
# day 2020-06-23 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.56%
# net daily return: 0.56%
# cumulative net return so far: 0.56%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.015056138627984605
# position_CVX: -1.0
# times_ret2： 0.017914191074374308
# ===========
# day 2020-06-24 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 44.5  and sell CVX: 2.0 * 87.63999938964844
# long position on XOM and short position on CVX
# gross daily return: -0.29%
# net daily return: -0.33%
# cumulative net return so far: -0.33%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.03431479521569214
# position_CVX: -1.0
# times_ret2： -0.030826140883557618
# ===========
# day 2020-06-25 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: -0.35%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.016047702431917665
# position_CVX: -1.0
# times_ret2： 0.01399490050064034
# ===========
# day 2020-06-26 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.21%
# net daily return: 0.21%
# cumulative net return so far: 0.21%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.009025305248944182
# position_CVX: -1.0
# times_ret2： 0.017794059776094162
# ===========
# day 2020-06-29 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.88%
# net daily return: -0.88%
# cumulative net return so far: -0.88%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.022585020318892313
# position_CVX: -1.0
# times_ret2： -0.018043265155009758
# ===========
# day 2020-06-30 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.45%
# net daily return: -0.45%
# cumulative net return so far: -0.45%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.008464945191761997
# position_CVX: -1.0
# times_ret2： 0.00787485494616269
# ===========
# day 2020-07-01 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.06%
# net daily return: 0.06%
# cumulative net return so far: 0.06%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.007032612198653698
# position_CVX: -1.0
# times_ret2： 0.002944198204262838
# ===========
# day 2020-07-02 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.41%
# net daily return: 0.41%
# cumulative net return so far: 0.41%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.025906684545929815
# position_CVX: -1.0
# times_ret2： -0.025516564796404073
# ===========
# day 2020-07-06 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.04%
# net daily return: -0.04%
# cumulative net return so far: -0.04%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0023127262936292192
# position_CVX: 0
# times_ret2： 0.00046345633946032194
# ===========
# day 2020-07-07 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 43.2400016784668  and sell XOM: 1.0 * 43.2400016784668
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.04126098295040748
# position_CVX: 0
# times_ret2： -0.04180660884937326
# ===========
# day 2020-07-08 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.031189576801033292
# position_CVX: 0
# times_ret2： 0.030094338378686247
# ===========
# day 2020-07-09 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.0002344272256857849
# position_CVX: 0
# times_ret2： 0.00199458127712826
# ===========
# day 2020-07-10 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.03305203592253747
# position_CVX: 0
# times_ret2： 0.03454328917486316
# ===========
# day 2020-07-13 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.012707088204422679
# position_CVX: 0
# times_ret2： 0.006112064797437533
# ===========
# day 2020-07-14 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.007842309667081993
# position_CVX: 0
# times_ret2： -0.005962411777883259
# ===========
# day 2020-07-15 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.017163467535788235
# position_CVX: 0
# times_ret2： -0.013241264835485378
# ===========
# day 2020-07-16 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.023437510271940076
# position_CVX: 0
# times_ret2： -0.0220209398391763
# ===========
# day 2020-07-17 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.050588271197150814
# position_CVX: 0
# times_ret2： 0.07177205333078507
# ===========
# day 2020-07-20 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.02329229294481805
# position_CVX: -1.0
# times_ret2： -0.003829724001078616
# ===========
# day 2020-07-21 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 44.650001525878906  and sell CVX: 1.0 * 91.38999938964844
# long position on XOM and short position on CVX
# gross daily return: -1.95%
# net daily return: -1.97%
# cumulative net return so far: -1.97%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.0020637503170894966
# position_CVX: -1.0
# times_ret2： -0.0003295120715641753
# ===========
# day 2020-07-22 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.24%
# net daily return: 0.24%
# cumulative net return so far: 0.24%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.006178500069790593
# position_CVX: -1.0
# times_ret2： -0.009669320537925574
# ===========
# day 2020-07-23 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.35%
# net daily return: 0.35%
# cumulative net return so far: 0.35%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.014736343199430513
# position_CVX: -1.0
# times_ret2： 0.010096568177526022
# ===========
# day 2020-07-24 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.46%
# net daily return: 0.46%
# cumulative net return so far: 0.46%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.01179942049840188
# position_CVX: -1.0
# times_ret2： -0.021199475898144526
# ===========
# day 2020-07-27 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.94%
# net daily return: 0.94%
# cumulative net return so far: 0.94%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.011021803688755494
# position_CVX: -1.0
# times_ret2： 0.010773191312952735
# ===========
# day 2020-07-28 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.02%
# net daily return: 0.02%
# cumulative net return so far: 0.02%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.04905745871670908
# position_CVX: 1.0
# times_ret2： -0.0421894422630511
# ===========
# day 2020-07-29 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 44.029998779296875  and sell XOM: 2.0 * 44.029998779296875
# long position on CVX and short position on XOM
# gross daily return: 0.69%
# net daily return: 0.65%
# cumulative net return so far: 0.65%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.005015593611825908
# position_CVX: -1.0
# times_ret2： -0.027008163815054664
# ===========
# day 2020-07-30 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 41.869998931884766  and sell CVX: 2.0 * 86.2699966430664
# long position on XOM and short position on CVX
# gross daily return: 3.2%
# net daily return: 3.16%
# cumulative net return so far: 3.16%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.004039880264925744
# position_CVX: -1.0
# times_ret2： 0.010364487632637198
# ===========
# day 2020-07-31 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.63%
# net daily return: -0.63%
# cumulative net return so far: -0.63%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.028875768537351965
# position_CVX: 1.0
# times_ret2： 0.019808988958113005
# ===========
# day 2020-08-03 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 42.25  and sell XOM: 2.0 * 42.25
# long position on CVX and short position on XOM
# gross daily return: -0.91%
# net daily return: -0.95%
# cumulative net return so far: -0.95%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.00874159748670511
# position_CVX: -1.0
# times_ret2： 0.008209031125089972
# ===========
# day 2020-08-04 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 43.470001220703125  and sell CVX: 2.0 * 86.48999786376953
# long position on XOM and short position on CVX
# gross daily return: 0.05%
# net daily return: 0.01%
# cumulative net return so far: 0.01%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.004789032879820798
# position_CVX: 1.0
# times_ret2： 0.0030963793797056383
# ===========
# day 2020-08-05 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 43.849998474121094  and sell XOM: 2.0 * 43.849998474121094
# long position on CVX and short position on XOM
# gross daily return: 0.79%
# net daily return: 0.75%
# cumulative net return so far: 0.75%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0045829689673848595
# position_CVX: 1.0
# times_ret2： -0.007659748023265522
# ===========
# day 2020-08-06 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.31%
# net daily return: -0.31%
# cumulative net return so far: -0.31%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.024631669628238262
# position_CVX: 1.0
# times_ret2： 0.03375576269771163
# ===========
# day 2020-08-07 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.91%
# net daily return: 0.91%
# cumulative net return so far: 0.91%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.010334821759527602
# position_CVX: 1.0
# times_ret2： -0.001225906678215427
# ===========
# day 2020-08-10 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.16%
# net daily return: -1.16%
# cumulative net return so far: -1.16%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.01956862451029029
# position_CVX: 1.0
# times_ret2： 0.012274028569621453
# ===========
# day 2020-08-11 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 3.18%
# net daily return: 3.18%
# cumulative net return so far: 3.18%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.02449539186475358
# position_CVX: -1.0
# times_ret2： -0.009920651606798225
# ===========
# day 2020-08-12 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 44.09000015258789  and sell CVX: 2.0 * 90.72000122070312
# long position on XOM and short position on CVX
# gross daily return: -1.46%
# net daily return: -1.5%
# cumulative net return so far: -1.5%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.004417634243689905
# position_CVX: 0
# times_ret2： 0.00590067669892691
# ===========
# day 2020-08-13 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 43.0099983215332  and sell XOM: 1.0 * 43.0099983215332
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.012962994523172067
# position_CVX: -1.0
# times_ret2： 0.004648568633519368
# ===========
# day 2020-08-14 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 43.20000076293945  and sell CVX: 1.0 * 90.3499984741211
# long position on XOM and short position on CVX
# gross daily return: -1.76%
# net daily return: -1.78%
# cumulative net return so far: -1.78%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.004924931695089008
# position_CVX: -1.0
# times_ret2： -0.03459292173377304
# ===========
# day 2020-08-17 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 2.97%
# net daily return: 2.97%
# cumulative net return so far: 2.97%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.01107709680232527
# position_CVX: -1.0
# times_ret2： -0.014150381178074989
# ===========
# day 2020-08-18 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.31%
# net daily return: 0.31%
# cumulative net return so far: 0.31%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.015252607331091905
# position_CVX: -1.0
# times_ret2： -0.018289175161679716
# ===========
# day 2020-08-19 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.3%
# net daily return: 0.3%
# cumulative net return so far: 0.3%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.007502453426441957
# position_CVX: 1.0
# times_ret2： 0.003183637309674525
# ===========
# day 2020-08-20 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 41.31999969482422  and sell XOM: 2.0 * 41.31999969482422
# long position on CVX and short position on XOM
# gross daily return: 1.07%
# net daily return: 1.03%
# cumulative net return so far: 1.03%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.02950507068259456
# position_CVX: 1.0
# times_ret2： 0.024917666567488173
# ===========
# day 2020-08-21 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.46%
# net daily return: -0.46%
# cumulative net return so far: -0.46%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.03173851524975335
# position_CVX: 1.0
# times_ret2： -0.012270639131550909
# ===========
# day 2020-08-24 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 1.95%
# net daily return: 1.95%
# cumulative net return so far: 1.95%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.021281867021784362
# position_CVX: 1.0
# times_ret2： -0.01567396397504839
# ===========
# day 2020-08-25 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.56%
# net daily return: 0.56%
# cumulative net return so far: 0.56%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.006748229302501518
# position_CVX: 1.0
# times_ret2： 0.0015334381302709588
# ===========
# day 2020-08-26 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.83%
# net daily return: 0.83%
# cumulative net return so far: 0.83%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.023905307199746373
# position_CVX: 1.0
# times_ret2： 0.008479490757929309
# ===========
# day 2020-08-27 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.54%
# net daily return: -1.54%
# cumulative net return so far: -1.54%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.01843204780812402
# position_CVX: 1.0
# times_ret2： -0.019852820305612418
# ===========
# day 2020-08-28 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.14%
# net daily return: -0.14%
# cumulative net return so far: -0.14%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.012769112144940142
# position_CVX: 1.0
# times_ret2： -0.01012746897450778
# ===========
# day 2020-08-31 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: 0.26%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.006086778508984536
# position_CVX: 1.0
# times_ret2： 0.0013240323534808862
# ===========
# day 2020-09-01 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.74%
# net daily return: 0.74%
# cumulative net return so far: 0.74%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0020412865312758877
# position_CVX: 1.0
# times_ret2： -0.010938858461391754
# ===========
# day 2020-09-02 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: -0.89%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0007670360222120642
# position_CVX: 1.0
# times_ret2： -0.004253749140904928
# ===========
# day 2020-09-03 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: -0.35%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.023029720668122478
# position_CVX: 1.0
# times_ret2： -0.03612839098556264
# ===========
# day 2020-09-04 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.31%
# net daily return: -1.31%
# cumulative net return so far: -1.31%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0060240843477716854
# position_CVX: 1.0
# times_ret2： 0.01342278766884264
# ===========
# day 2020-09-08 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 1.94%
# net daily return: 1.94%
# cumulative net return so far: 1.94%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.025032957676965006
# position_CVX: 1.0
# times_ret2： -0.023491156842355365
# ===========
# day 2020-09-09 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.15%
# net daily return: 0.15%
# cumulative net return so far: 0.15%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.0027026614627322365
# position_CVX: 1.0
# times_ret2： -0.005886104612810916
# ===========
# day 2020-09-10 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: -0.32%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.006504110258599205
# position_CVX: 1.0
# times_ret2： -0.005148687261022911
# ===========
# day 2020-09-11 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.14%
# net daily return: 0.14%
# cumulative net return so far: 0.14%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.01063828126764077
# position_CVX: 1.0
# times_ret2： -0.012162018764026228
# ===========
# day 2020-09-14 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.15%
# net daily return: -0.15%
# cumulative net return so far: -0.15%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.042459357488033866
# position_CVX: 1.0
# times_ret2： 0.028945633642962543
# ===========
# day 2020-09-15 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.35%
# net daily return: -1.35%
# cumulative net return so far: -1.35%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.00026453678569648975
# position_CVX: 1.0
# times_ret2： 0.0029277413961481535
# ===========
# day 2020-09-16 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: 0.32%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.016137582610147083
# position_CVX: 1.0
# times_ret2： -0.007361363425753997
# ===========
# day 2020-09-17 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.88%
# net daily return: 0.88%
# cumulative net return so far: 0.88%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.02043555659040519
# position_CVX: 0
# times_ret2： -0.02442137904453756
# ===========
# day 2020-09-18 00:00:00
#
# old_signal: -1.0 →signal: 0
# buy XOM: 1.0 * 37.189998626708984  and sell CVX: 1.0 * 78.20999908447266
# long position on XOM and short position on CVX
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.024704955211077517
# position_CVX: 0
# times_ret2： -0.010091798711182376
# ===========
# day 2020-09-21 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.032085545421203565
# position_CVX: 0
# times_ret2： -0.0473984097565745
# ===========
# day 2020-09-22 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.002035466591060464
# position_CVX: 0
# times_ret2： -0.0020846963564470355
# ===========
# day 2020-09-23 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.009324000514850717
# position_CVX: 0
# times_ret2： 0.0004178102788554572
# ===========
# day 2020-09-24 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.019341858990990612
# position_CVX: 0
# times_ret2： 0.02923567340371669
# ===========
# day 2020-09-25 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.029170279069239857
# position_CVX: 0
# times_ret2： -0.02745838997588579
# ===========
# day 2020-09-28 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.0014586655057879927
# position_CVX: 0
# times_ret2： 0.0013907993323909462
# ===========
# day 2020-09-29 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.03495487034474731
# position_CVX: 0
# times_ret2： -0.021944469875759598
# ===========
# day 2020-09-30 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.004527664384027741
# position_CVX: 0
# times_ret2： 0.010934454593617193
# ===========
# day 2020-10-01 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.02304433434746289
# position_CVX: -1.0
# times_ret2： 0.02121076633026875
# ===========
# day 2020-10-02 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 32.97999954223633  and sell CVX: 1.0 * 71.19000244140625
# long position on XOM and short position on CVX
# gross daily return: 0.18%
# net daily return: 0.16%
# cumulative net return so far: 0.16%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.01037351130429065
# position_CVX: -1.0
# times_ret2： -0.005501979549863645
# ===========
# day 2020-10-05 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.49%
# net daily return: -0.49%
# cumulative net return so far: -0.49%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.003294417860506549
# position_CVX: -1.0
# times_ret2： 0.020470202836361917
# ===========
# day 2020-10-06 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -1.72%
# net daily return: -1.72%
# cumulative net return so far: -1.72%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.05253726332934927
# position_CVX: -1.0
# times_ret2： 0.019517517826393993
# ===========
# day 2020-10-07 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 3.3%
# net daily return: 3.3%
# cumulative net return so far: 3.3%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.014747494833227126
# position_CVX: -1.0
# times_ret2： -0.016219106632603175
# ===========
# day 2020-10-08 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.15%
# net daily return: 0.15%
# cumulative net return so far: 0.15%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.0031663962301919923
# position_CVX: -1.0
# times_ret2： 0.006891920759871217
# ===========
# day 2020-10-09 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -1.01%
# net daily return: -1.01%
# cumulative net return so far: -1.01%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.011839440796021394
# position_CVX: -1.0
# times_ret2： -0.014897336981981146
# ===========
# day 2020-10-12 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.31%
# net daily return: 0.31%
# cumulative net return so far: 0.31%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.0020455783847801445
# position_CVX: -1.0
# times_ret2： -0.0061308524289070965
# ===========
# day 2020-10-13 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.41%
# net daily return: 0.41%
# cumulative net return so far: 0.41%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.008784750326678914
# position_CVX: 0
# times_ret2： 0.00767656218526791
# ===========
# day 2020-10-14 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 34.150001525878906  and sell XOM: 1.0 * 34.150001525878906
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.010159717882935015
# position_CVX: 0
# times_ret2： -0.008434263754108273
# ===========
# day 2020-10-15 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.019941358815363075
# position_CVX: 0
# times_ret2： -0.022088086484196245
# ===========
# day 2020-10-16 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.008378294713801804
# position_CVX: 0
# times_ret2： 0.005611693781272686
# ===========
# day 2020-10-19 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.01602376567662256
# position_CVX: 0
# times_ret2： -0.011300189106378422
# ===========
# day 2020-10-20 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.05126660949222317
# position_CVX: 1.0
# times_ret2： 0.035699148881702225
# ===========
# day 2020-10-21 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 33.15999984741211  and sell XOM: 1.0 * 33.15999984741211
# long position on CVX and short position on XOM
# gross daily return: -1.56%
# net daily return: -1.58%
# cumulative net return so far: -1.58%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.02008034281937421
# position_CVX: -1.0
# times_ret2： -0.01130792661853075
# ===========
# day 2020-10-22 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 34.86000061035156  and sell CVX: 2.0 * 73.4000015258789
# long position on XOM and short position on CVX
# gross daily return: -0.88%
# net daily return: -0.92%
# cumulative net return so far: -0.92%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.023711984101556727
# position_CVX: -1.0
# times_ret2： -0.022461034315454542
# ===========
# day 2020-10-23 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.13%
# net daily return: -0.13%
# cumulative net return so far: -0.13%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.015892018097336424
# position_CVX: 1.0
# times_ret2： -0.02015788350665626
# ===========
# day 2020-10-26 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 33.349998474121094  and sell XOM: 2.0 * 33.349998474121094
# long position on CVX and short position on XOM
# gross daily return: -0.43%
# net daily return: -0.47%
# cumulative net return so far: -0.47%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.03808653295621833
# position_CVX: -1.0
# times_ret2： -0.037836351632647536
# ===========
# day 2020-10-27 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 32.81999969482422  and sell CVX: 2.0 * 69.51000213623047
# long position on XOM and short position on CVX
# gross daily return: -0.03%
# net daily return: -0.07%
# cumulative net return so far: -0.07%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.04434594676630388
# position_CVX: -1.0
# times_ret2： 0.02870822184792665
# ===========
# day 2020-10-28 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.56%
# net daily return: 1.56%
# cumulative net return so far: 1.56%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.010615780280850529
# position_CVX: 0
# times_ret2： 0.01017437379640218
# ===========
# day 2020-10-29 00:00:00
# ...
# no trading
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: -0.32%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.027650569075818865
# position_CVX: -1.0
# times_ret2： -0.02645607329159183
# ===========
# day 2021-07-15 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.12%
# net daily return: -0.12%
# cumulative net return so far: -0.12%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.034368479260145746
# position_CVX: 0
# times_ret2： -0.026972252971282362
# ===========
# day 2021-07-16 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 57.31999969482422  and sell XOM: 1.0 * 57.31999969482422
# long position on CVX and short position on XOM
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.011020788205382992
# position_CVX: 0
# times_ret2： 0.00593997186601114
# ===========
# day 2021-07-19 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.032165819630257886
# position_CVX: 0
# times_ret2： 0.03408267851582081
# ===========
# day 2021-07-20 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.01125342330453838
# position_CVX: 0
# times_ret2： -0.010018032489052864
# ===========
# day 2021-07-21 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0012256994235004814
# position_CVX: 0
# times_ret2： 0.00040478562690626774
# ===========
# day 2021-07-22 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.025245417314097462
# position_CVX: 0
# times_ret2： 0.021140970311422258
# ===========
# day 2021-07-23 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.011114872029234335
# position_CVX: 0
# times_ret2： -0.003367967787705317
# ===========
# day 2021-07-26 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.006743893780045029
# position_CVX: 0
# times_ret2： 0.005665437743428203
# ===========
# day 2021-07-27 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.012195105970217224
# position_CVX: 0
# times_ret2： 0.01373788679043253
# ===========
# day 2021-07-28 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.023078238644300697
# position_CVX: 0
# times_ret2： -0.007409594798593155
# ===========
# day 2021-07-29 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.00017373868826631167
# position_CVX: -1.0
# times_ret2： -0.001768002254122325
# ===========
# day 2021-07-30 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 57.56999969482422  and sell CVX: 1.0 * 101.80999755859375
# long position on XOM and short position on CVX
# gross daily return: 0.19%
# net daily return: 0.17%
# cumulative net return so far: 0.17%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.010767608755968938
# position_CVX: -1.0
# times_ret2： 0.009544438127695676
# ===========
# day 2021-08-02 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: 0.12%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.023367707775316382
# position_CVX: -1.0
# times_ret2： -0.02241710971314892
# ===========
# day 2021-08-03 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: -0.1%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.00633357863098416
# position_CVX: -1.0
# times_ret2： 0.00927218621016257
# ===========
# day 2021-08-04 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.29%
# net daily return: -0.29%
# cumulative net return so far: -0.29%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.011538458716940037
# position_CVX: -1.0
# times_ret2： 0.0071124525084713675
# ===========
# day 2021-08-05 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.44%
# net daily return: 0.44%
# cumulative net return so far: 0.44%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.01140684134894443
# position_CVX: -1.0
# times_ret2： -0.016674811173415183
# ===========
# day 2021-08-06 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: 0.53%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.01713285890148586
# position_CVX: 0
# times_ret2： 0.018254382354660148
# ===========
# day 2021-08-09 00:00:00
#
# old_signal: 1.0 →signal: 0
# buy CVX: 1.0 * 57.20000076293945  and sell XOM: 1.0 * 57.20000076293945
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.0029219348238846976
# position_CVX: 0
# times_ret2： 0.007543070427651122
# ===========
# day 2021-08-10 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.017137961030856075
# position_CVX: -1.0
# times_ret2： -0.0020417995876343964
# ===========
# day 2021-08-11 00:00:00
#
# old_signal: 0 →signal: 1.0
# buy XOM: 1.0 * 58.349998474121094  and sell CVX: 1.0 * 102.8499984741211
# long position on XOM and short position on CVX
# gross daily return: -1.51%
# net daily return: -1.53%
# cumulative net return so far: -1.53%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.010113304826313896
# position_CVX: -1.0
# times_ret2： -0.006625100440563303
# ===========
# day 2021-08-12 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: -0.35%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.014620430233609039
# position_CVX: -1.0
# times_ret2： -0.010200087533011049
# ===========
# day 2021-08-13 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.44%
# net daily return: -0.44%
# cumulative net return so far: -0.44%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.006792943560004594
# position_CVX: -1.0
# times_ret2： -0.0018826279771989585
# ===========
# day 2021-08-16 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: -0.49%
# net daily return: -0.49%
# cumulative net return so far: -0.49%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： -0.021058350516978686
# position_CVX: -1.0
# times_ret2： -0.04000800431239149
# ===========
# day 2021-08-17 00:00:00
#
# old_signal: 1.0 →signal: 1.0
# no trading
# gross daily return: 1.89%
# net daily return: 1.89%
# cumulative net return so far: 1.89%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.03052031377165343
# position_CVX: 1.0
# times_ret2： -0.02492240029753856
# ===========
# day 2021-08-18 00:00:00
#
# old_signal: 1.0 →signal: -1.0
# buy CVX: 2.0 * 54.38999938964844  and sell XOM: 2.0 * 54.38999938964844
# long position on CVX and short position on XOM
# gross daily return: 0.56%
# net daily return: 0.52%
# cumulative net return so far: 0.52%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.00018968587743795062
# position_CVX: 1.0
# times_ret2： 0.0001060784402731052
# ===========
# day 2021-08-19 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.01%
# net daily return: -0.01%
# cumulative net return so far: -0.01%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.04114520477596617
# position_CVX: 1.0
# times_ret2： 0.02576882530790625
# ===========
# day 2021-08-20 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -1.54%
# net daily return: -1.54%
# cumulative net return so far: -1.54%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.008195242472954778
# position_CVX: 1.0
# times_ret2： 0.01147516739828025
# ===========
# day 2021-08-23 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.33%
# net daily return: 0.33%
# cumulative net return so far: 0.33%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.0018063307987463695
# position_CVX: 1.0
# times_ret2： 0.006847974483011887
# ===========
# day 2021-08-24 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.5%
# net daily return: 0.5%
# cumulative net return so far: 0.5%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.013523260230452805
# position_CVX: 1.0
# times_ret2： -0.013095126256757017
# ===========
# day 2021-08-25 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.04%
# net daily return: 0.04%
# cumulative net return so far: 0.04%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.019374911186790023
# position_CVX: 1.0
# times_ret2： 0.014606029120712627
# ===========
# day 2021-08-26 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.48%
# net daily return: -0.48%
# cumulative net return so far: -0.48%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.010937791022855303
# position_CVX: 1.0
# times_ret2： -0.0025344687910271446
# ===========
# day 2021-08-27 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: 0.84%
# net daily return: 0.84%
# cumulative net return so far: 0.84%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.011602599554366488
# position_CVX: 0
# times_ret2： -0.016465115932834062
# ===========
# day 2021-08-30 00:00:00
#
# old_signal: -1.0 →signal: 0
# buy XOM: 1.0 * 55.15999984741211  and sell CVX: 1.0 * 98.38999938964844
# long position on XOM and short position on CVX
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.013756419547006793
# position_CVX: 0
# times_ret2： -0.010953783149373453
# ===========
# day 2021-08-31 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.024363053043304772
# position_CVX: 0
# times_ret2： 0.02089645825024844
# ===========
# day 2021-09-01 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0038126886744495048
# position_CVX: 0
# times_ret2： -0.0022515732551888767
# ===========
# day 2021-09-02 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0058319610179228265
# position_CVX: 0
# times_ret2： -0.0044107120176231085
# ===========
# day 2021-09-03 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.009165902969624717
# position_CVX: 0
# times_ret2： -0.00690292793939995
# ===========
# day 2021-09-07 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.0007400724531354541
# position_CVX: 0
# times_ret2： -0.004046056563107747
# ===========
# day 2021-09-08 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.002033658902592883
# position_CVX: 0
# times_ret2： 0.0007291634877522046
# ===========
# day 2021-09-09 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.025750266792070597
# position_CVX: 0
# times_ret2： 0.01977726170411631
# ===========
# day 2021-09-10 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.014267601879529024
# position_CVX: 0
# times_ret2： -0.018066798513899585
# ===========
# day 2021-09-13 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： 0.033711914183991665
# position_CVX: 0
# times_ret2： 0.02120583139545129
# ===========
# day 2021-09-14 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： -0.010634500063690933
# position_CVX: 1.0
# times_ret2： -0.009364802411957363
# ===========
# day 2021-09-15 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 56.41999816894531  and sell XOM: 1.0 * 56.41999816894531
# long position on CVX and short position on XOM
# gross daily return: 0.13%
# net daily return: 0.11%
# cumulative net return so far: 0.11%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.011823716428169484
# position_CVX: 0
# times_ret2： -0.005754187837544111
# ===========
# day 2021-09-16 00:00:00
#
# old_signal: -1.0 →signal: 0
# buy XOM: 1.0 * 55.81999969482422  and sell CVX: 1.0 * 97.31999969482422
# long position on XOM and short position on CVX
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.026649768396837525
# position_CVX: 0
# times_ret2： -0.020463035481808944
# ===========
# day 2021-09-17 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: 0
# times_ret1： -0.0009312579314478819
# position_CVX: 0
# times_ret2： 0.0007385492269018634
# ===========
# day 2021-09-20 00:00:00
#
# old_signal: 0 →signal: 0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.02926919673170625
# position_CVX: 1.0
# times_ret2： 0.02941487570280321
# ===========
# day 2021-09-21 00:00:00
#
# old_signal: 0 →signal: -1.0
# buy CVX: 1.0 * 53.63999938964844  and sell XOM: 1.0 * 53.63999938964844
# long position on CVX and short position on XOM
# gross daily return: 0.01%
# net daily return: -0.01%
# cumulative net return so far: -0.01%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.0338707259118205
# position_CVX: 1.0
# times_ret2： 0.02478490561319968
# ===========
# day 2021-09-22 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.91%
# net daily return: -0.91%
# cumulative net return so far: -0.91%
# —————————next day—————————
# position_XOM: -1.0
# times_ret1： 0.008934798619010031
# position_CVX: 1.0
# times_ret2： 0.005396771224295938
# ===========
# day 2021-09-23 00:00:00
#
# old_signal: -1.0 →signal: -1.0
# no trading
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: -0.35%
# —————————next day—————————
# position_XOM: 1.0
# times_ret1： 0.02969263899881791
# position_CVX: -1.0
# times_ret2： 0.023558675770673165
# ===========
# day 2021-09-24 00:00:00
#
# old_signal: -1.0 →signal: 1.0
# buy XOM: 2.0 * 57.59000015258789  and sell CVX: 2.0 * 100.5999984741211
# long position on XOM and short position on CVX
# gross daily return: 0.61%
# net daily return: 0.57%
# cumulative net return so far: 0.57%
# —————————next day—————————

# %% [markdown]
# > day 2020-07-29 ->30 ; -1 ->1, 1-> -1

# %% [markdown]
# #### With $β$ loading position

# %%
#moving in a loop through the sample
for t in range(window, len(raw_data)-1): ###
    old_signal = signal
    old_position0 = position0
    old_position1 = position1

    #specifying the subsample
    data = raw_data[t-window:t]

    #stock 2 = a + b* stock 1
    #OLS parameters as starting values
    reg = sm.OLS(np.array(data[stock2]), sm.add_constant(np.array(data[stock1])))
    res = reg.fit()
    a0 = res.params[0]
    b0 = res.params[1] ###
    ####

    if unbiased == 1:
        #defining the KPSS function (unbiased one-parameter forecast)
        def KPSS(b):
            a = np.average(data[stock2] - b*data[stock1])
            resid = np.array(data[stock2] - (a + b*data[stock1]))
            cum_resid = np.cumsum(resid)
            st_error = (np.sum(resid**2)/(len(resid)-2))**(1/2)
            KPSS = np.sum(cum_resid**2)/(len(resid)**2*st_error**2)
            return KPSS
        #minimising the KPSS function (maximising the stationarity)
        res = spop.minimize(KPSS, b0, method='Nelder-Mead')
        KPSS_opt = res.fun
        #retrieving optimal parameters
        b_opt = float(res.x)
        a_opt = np.average(data[stock2] - b_opt*data[stock1])

    else:
        #defining the KPSS function (two-parameter)
        def KPSS2(kpss_params):
            a = kpss_params[0]
            b = kpss_params[1]
            resid = np.array(data[stock2] - (a + b*data[stock1]))
            cum_resid = np.cumsum(resid)
            st_error = (np.sum(resid**2)/(len(resid)-2))**(1/2)
            KPSS = np.sum(cum_resid**2)/(len(resid)**2*st_error**2)
            return KPSS
        #minimising the KPSS function (maximising the stationarity)
        res = spop.minimize(KPSS2, [a0, b0], method='Nelder-Mead')
        #retrieving optimal parameters
        KPSS_opt = res.fun
        a_opt = res.x[0]
        b_opt = res.x[1]


    print('optimal slope:',b_opt)
    #simulate trading
    #first check whether stop-loss is violated
    if current_return < stop_loss:
        signal = 0
        print('stop-loss triggered')
    #if we are already in position, check whether the equilibrium is restored, continue in position if not
    elif np.sign(raw_data[stock2][t] - (a_opt + b_opt*raw_data[stock1][t])) == old_signal:
        singal = old_signal
    else:
        #only trade if the pair is cointegrated
        if KPSS_opt > KPSS_max:
            signal = 0
        #only trade if there are large enough profit opportunities (optimal entry)
        elif abs(raw_data[stock2][t]/(a_opt + b_opt*raw_data[stock1][t])-1) < entry:
            signal = 0
        #comparing % ($stock2 to dynamic equilibrium -1) diverge  large enough (>entry) and stock1 diverge relatively

        else:
            signal = np.sign(raw_data[stock2][t] - (a_opt + b_opt*raw_data[stock1][t]))
        #signal to decide long/short the pair (stock2 / stock1)

    #calculate strategy returns with beta loading
    if beta_loading == 1:
        rets_stk1 = np.array(raw_data[stock1][t-window:t-1])/np.array(raw_data[stock1][t-window+1:t]) - 1
        rets_stk2 = np.array(raw_data[stock2][t-window:t-1])/np.array(raw_data[stock2][t-window+1:t]) - 1
        rets_mkt = np.array(raw_data['market'][t-window:t-1])/np.array(raw_data['market'][t-window+1:t]) - 1
        reg = sm.OLS(rets_stk1, sm.add_constant(rets_mkt))
        res = reg.fit()
        beta_stk1 = res.params[1]
        print('beta_stock1:',beta_stk1)
        reg = sm.OLS(rets_stk2, sm.add_constant(rets_mkt))
        res = reg.fit()
        beta_stk2 = res.params[1]
        print('beta_stock2:',beta_stk2)
        position0 = beta_stk2*signal
        position1 = -beta_stk1*signal
    #calculate strategy returns without beta loading
    else:
        position0 = signal
        position1 = -signal
    print(f'position_{stock1}:',position0)
    print('times_ret1：',(raw_data[stock1][t+1]/raw_data[stock1][t] - 1))
    print(f'position_{stock2}:',position1)
    print('times_ret2：',(raw_data[stock2][t+1]/raw_data[stock2][t] - 1))
    print("===========")
    #calculating returns
    gross = position0*(raw_data[stock1][t+1]/raw_data[stock1][t] - 1) + position1*(raw_data[stock2][t+1]/raw_data[stock2][t] - 1)
    net = gross - fee*(abs(position0 - old_position0) + abs(position1 - old_position1))
    market = raw_data['market'][t+1]/raw_data['market'][t] - 1
    if signal == old_signal:
        current_return = (1+current_return)*(1+gross)-1
    else:
        current_return = gross
    #populating arrays
    #DF_stats = np.append(DF_stats, DF_opt)
    KPSS_stats = np.append(KPSS_stats, KPSS_opt)
    signals = np.append(signals, signal)
    gross_returns = np.append(gross_returns, gross)
    net_returns = np.append(net_returns, net)
    market_returns = np.append(market_returns, market)

    #interface: reporting daily positions and realised returns
    print('day '+str(raw_data.index[t]))
    print('')
    print('old_signal:',old_position0, '→signal:',position0)
    if position0 == old_position0: #signal == 0: #position0 == 0:
        print('no trading')
    elif  position0 > old_position0: #signal == 1: # position0 > 0:
        print(f'buy {stock1}:',(position0 - old_position0),'*',raw_data[stock1][t],f' and sell {stock2}:',abs(position1 - old_position1),'*',raw_data[stock2][t])
        print('long position on '+stock1+' and short position on '+stock2)
        traded_date = raw_data.index[t]
    else:
        print(f'buy {stock2}:',(position1 - old_position1),'*',raw_data[stock2][t],f' and sell {stock1}:',abs(position0 - old_position0),'*',raw_data[stock1][t])
        print('long position on '+stock2+' and short position on '+stock1)
        traded_date = raw_data.index[t]

    traded_dates = np.append(traded_dates, traded_date)
    print('gross daily return: '+str(round(gross*100,2))+'%')
    print('net daily return: '+str(round(net*100,2))+'%')
    print('cumulative net return so far: '+str(round(np.prod(1+net)*100-100,2))+'%')
    print('—————————next day—————————')
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# position_XOM: 1.362925869574978
# times_ret1： -0.02329229294481805
# position_CVX: -1.454853816867008
# times_ret2： -0.003829724001078616
# ===========
# day 2020-07-21 00:00:00
#
# old_signal: 0.0 →signal: 1.362925869574978
# buy XOM: 1.362925869574978 * 44.650001525878906  and sell CVX: 1.454853816867008 * 91.38999938964844
# long position on XOM and short position on CVX
# gross daily return: -2.62%
# net daily return: -2.65%
# cumulative net return so far: -2.65%
# —————————next day—————————
# optimal slope: 1.1148600943442921
# beta_stock1: 1.4349424610011101
# beta_stock2: 1.3395672645429086
# position_XOM: 1.3395672645429086
# times_ret1： 0.0020637503170894966
# position_CVX: -1.4349424610011101
# times_ret2： -0.0003295120715641753
# ===========
# day 2020-07-22 00:00:00
#
# old_signal: 1.362925869574978 →signal: 1.3395672645429086
# buy CVX: 0.019911355865897873 * 43.61000061035156  and sell XOM: 0.023358605032069324 * 43.61000061035156
# long position on CVX and short position on XOM
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: 0.32%
# —————————next day—————————
# optimal slope: 0.28125750189759474
# beta_stock1: 1.3981844352157615
# beta_stock2: 1.332457028521298
# position_XOM: 1.332457028521298
# times_ret1： -0.006178500069790593
# position_CVX: -1.3981844352157615
# times_ret2： -0.009669320537925574
# ===========
# day 2020-07-23 00:00:00
#
# old_signal: 1.3395672645429086 →signal: 1.332457028521298
# buy CVX: 0.03675802578534859 * 43.70000076293945  and sell XOM: 0.00711023602161065 * 43.70000076293945
# long position on CVX and short position on XOM
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: 0.53%
# —————————next day—————————
# optimal slope: -2.3128605133550737
# beta_stock1: 1.1454452779624262
# beta_stock2: 1.1377196838164474
# position_XOM: 1.1377196838164474
# times_ret1： 0.014736343199430513
# position_CVX: -1.1454452779624262
# times_ret2： 0.010096568177526022
# ===========
# day 2020-07-24 00:00:00
#
# old_signal: 1.332457028521298 →signal: 1.1377196838164474
# buy CVX: 0.2527391572533353 * 43.43000030517578  and sell XOM: 0.1947373447048506 * 43.43000030517578
# long position on CVX and short position on XOM
# gross daily return: 0.52%
# net daily return: 0.52%
# cumulative net return so far: 0.52%
# —————————next day—————————
# optimal slope: -5.031810208004007
# beta_stock1: 1.0984934151116368
# beta_stock2: 1.1139773291091235
# position_XOM: 1.1139773291091235
# times_ret1： -0.01179942049840188
# position_CVX: -1.0984934151116368
# times_ret2： -0.021199475898144526
# ===========
# day 2020-07-27 00:00:00
#
# old_signal: 1.1377196838164474 →signal: 1.1139773291091235
# buy CVX: 0.04695186285078945 * 44.06999969482422  and sell XOM: 0.023742354707323887 * 44.06999969482422
# long position on CVX and short position on XOM
# gross daily return: 1.01%
# net daily return: 1.01%
# cumulative net return so far: 1.01%
# —————————next day—————————
# optimal slope: 3659519811040.6562
# beta_stock1: 1.0535273879744322
# beta_stock2: 1.0838084226730227
# position_XOM: 1.0838084226730227
# times_ret1： 0.011021803688755494
# position_CVX: -1.0535273879744322
# times_ret2： 0.010773191312952735
# ===========
# day 2020-07-28 00:00:00
#
# old_signal: 1.1139773291091235 →signal: 1.0838084226730227
# buy CVX: 0.044966027137204545 * 43.54999923706055  and sell XOM: 0.030168906436100817 * 43.54999923706055
# long position on CVX and short position on XOM
# gross daily return: 0.06%
# net daily return: 0.06%
# cumulative net return so far: 0.06%
# —————————next day—————————
# optimal slope: 421.60470920050494
# beta_stock1: 1.0295294460900024
# beta_stock2: 1.1662370968527722
# position_XOM: -1.1662370968527722
# times_ret1： -0.04905745871670908
# position_CVX: 1.0295294460900024
# times_ret2： -0.0421894422630511
# ===========
# day 2020-07-29 00:00:00
#
# old_signal: 1.0838084226730227 →signal: -1.1662370968527722
# buy CVX: 2.0830568340644344 * 44.029998779296875  and sell XOM: 2.250045519525795 * 44.029998779296875
# long position on CVX and short position on XOM
# gross daily return: 1.38%
# net daily return: 1.33%
# cumulative net return so far: 1.33%
# —————————next day—————————
# optimal slope: 14.760956396277983
# beta_stock1: 1.0701905861132832
# beta_stock2: 1.137368849595652
# position_XOM: 1.137368849595652
# times_ret1： 0.005015593611825908
# position_CVX: -1.0701905861132832
# times_ret2： -0.027008163815054664
# ===========
# day 2020-07-30 00:00:00
#
# old_signal: -1.1662370968527722 →signal: 1.137368849595652
# buy XOM: 2.303605946448424 * 41.869998931884766  and sell CVX: 2.099720032203286 * 86.2699966430664
# long position on XOM and short position on CVX
# gross daily return: 3.46%
# net daily return: 3.42%
# cumulative net return so far: 3.42%
# —————————next day—————————
# optimal slope: 27.817021297975767
# beta_stock1: 1.2995452773495098
# beta_stock2: 1.332441096492821
# position_XOM: 1.332441096492821
# times_ret1： 0.004039880264925744
# position_CVX: -1.2995452773495098
# times_ret2： 0.010364487632637198
# ===========
# day 2020-07-31 00:00:00
#
# old_signal: 1.137368849595652 →signal: 1.332441096492821
# buy XOM: 0.19507224689716907 * 42.08000183105469  and sell CVX: 0.22935469123622654 * 83.94000244140625
# long position on XOM and short position on CVX
# gross daily return: -0.81%
# net daily return: -0.81%
# cumulative net return so far: -0.81%
# —————————next day—————————
# optimal slope: -39.24295654145281
# beta_stock1: 1.2878559962410194
# beta_stock2: 1.1955695195228087
# position_XOM: -1.1955695195228087
# times_ret1： 0.028875768537351965
# position_CVX: 1.2878559962410194
# times_ret2： 0.019808988958113005
# ===========
# day 2020-08-03 00:00:00
#
# old_signal: 1.332441096492821 →signal: -1.1955695195228087
# buy CVX: 2.587401273590529 * 42.25  and sell XOM: 2.5280106160156297 * 42.25
# long position on CVX and short position on XOM
# gross daily return: -0.9%
# net daily return: -0.95%
# cumulative net return so far: -0.95%
# —————————next day—————————
# optimal slope: -19.434503284321522
# beta_stock1: 1.372094599942455
# beta_stock2: 1.3361257150745778
# position_XOM: 1.3361257150745778
# times_ret1： 0.00874159748670511
# position_CVX: -1.372094599942455
# times_ret2： 0.008209031125089972
# ===========
# day 2020-08-04 00:00:00
#
# old_signal: -1.1955695195228087 →signal: 1.3361257150745778
# buy XOM: 2.5316952345973864 * 43.470001220703125  and sell CVX: 2.6599505961834744 * 86.48999786376953
# long position on XOM and short position on CVX
# gross daily return: 0.04%
# net daily return: -0.01%
# cumulative net return so far: -0.01%
# —————————next day—————————
# optimal slope: 12.698635726441463
# beta_stock1: 1.3238300230310591
# beta_stock2: 1.2754127784765983
# position_XOM: -1.2754127784765983
# times_ret1： -0.004789032879820798
# position_CVX: 1.3238300230310591
# times_ret2： 0.0030963793797056383
# ===========
# day 2020-08-05 00:00:00
#
# old_signal: 1.3361257150745778 →signal: -1.2754127784765983
# buy CVX: 2.6959246229735143 * 43.849998474121094  and sell XOM: 2.6115384935511763 * 43.849998474121094
# long position on CVX and short position on XOM
# gross daily return: 1.02%
# net daily return: 0.97%
# cumulative net return so far: 0.97%
# —————————next day—————————
# optimal slope: 7.819763386688668
# beta_stock1: 1.3812851979390064
# beta_stock2: 1.3167693160387843
# position_XOM: -1.3167693160387843
# times_ret1： -0.0045829689673848595
# position_CVX: 1.3812851979390064
# times_ret2： -0.007659748023265522
# ===========
# day 2020-08-06 00:00:00
#
# old_signal: -1.2754127784765983 →signal: -1.3167693160387843
# buy CVX: 0.05745517490794727 * 43.63999938964844  and sell XOM: 0.041356537562186046 * 43.63999938964844
# long position on CVX and short position on XOM
# gross daily return: -0.45%
# net daily return: -0.46%
# cumulative net return so far: -0.46%
# —————————next day—————————
# optimal slope: 7.614581077613915
# beta_stock1: 1.0802756200930776
# beta_stock2: 1.0368862360089508
# position_XOM: -1.0368862360089508
# times_ret1： 0.024631669628238262
# position_CVX: 1.0802756200930776
# times_ret2： 0.03375576269771163
# ===========
# day 2020-08-07 00:00:00
#
# old_signal: -1.3167693160387843 →signal: -1.0368862360089508
# buy XOM: 0.27988308002983353 * 43.439998626708984  and sell CVX: 0.30100957784592874 * 86.80000305175781
# long position on XOM and short position on CVX
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: 1.09%
# —————————next day—————————
# optimal slope: 17.253355283071045
# beta_stock1: 0.9333076375675796
# beta_stock2: 0.9021257114096383
# position_XOM: -0.9021257114096383
# times_ret1： 0.010334821759527602
# position_CVX: 0.9333076375675796
# times_ret2： -0.001225906678215427
# ===========
# day 2020-08-10 00:00:00
#
# old_signal: -1.0368862360089508 →signal: -0.9021257114096383
# buy XOM: 0.13476052459931254 * 44.5099983215332  and sell CVX: 0.14696798252549803 * 89.7300033569336
# long position on XOM and short position on CVX
# gross daily return: -1.05%
# net daily return: -1.05%
# cumulative net return so far: -1.05%
# —————————next day—————————
# optimal slope: 2776404429900.3066
# beta_stock1: 1.0808078448546832
# beta_stock2: 1.066695822402193
# position_XOM: -1.066695822402193
# times_ret1： -0.01956862451029029
# position_CVX: 1.0808078448546832
# times_ret2： 0.012274028569621453
# ===========
# day 2020-08-11 00:00:00
#
# old_signal: -0.9021257114096383 →signal: -1.066695822402193
# buy CVX: 0.14750020728710356 * 44.970001220703125  and sell XOM: 0.1645701109925547 * 44.970001220703125
# long position on CVX and short position on XOM
# gross daily return: 3.41%
# net daily return: 3.41%
# cumulative net return so far: 3.41%
# —————————next day—————————
# optimal slope: -10.034632748666294
# beta_stock1: 0.5874273306210865
# beta_stock2: 0.6982561550219072
# position_XOM: 0.6982561550219072
# times_ret1： -0.02449539186475358
# position_CVX: -0.5874273306210865
# times_ret2： -0.009920651606798225
# ===========
# day 2020-08-12 00:00:00
#
# old_signal: -1.066695822402193 →signal: 0.6982561550219072
# buy XOM: 1.7649519774241003 * 44.09000015258789  and sell CVX: 1.6682351754757696 * 90.72000122070312
# long position on XOM and short position on CVX
# gross daily return: -1.13%
# net daily return: -1.16%
# cumulative net return so far: -1.16%
# —————————next day—————————
# optimal slope: -4.936010352114938
# beta_stock1: 0.19466718384620788
# beta_stock2: 0.735216973032099
# position_XOM: 0.0
# times_ret1： 0.004417634243689905
# position_CVX: -0.0
# times_ret2： 0.00590067669892691
# ===========
# day 2020-08-13 00:00:00
#
# old_signal: 0.6982561550219072 →signal: 0.0
# buy CVX: 0.5874273306210865 * 43.0099983215332  and sell XOM: 0.6982561550219072 * 43.0099983215332
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.01%
# cumulative net return so far: -0.01%
# —————————next day—————————
# optimal slope: 206.1640375091188
# beta_stock1: 0.2692455469048438
# beta_stock2: 0.75544709802406
# position_XOM: 0.75544709802406
# times_ret1： -0.012962994523172067
# position_CVX: -0.2692455469048438
# times_ret2： 0.004648568633519368
# ===========
# day 2020-08-14 00:00:00
#
# old_signal: 0.0 →signal: 0.75544709802406
# buy XOM: 0.75544709802406 * 43.20000076293945  and sell CVX: 0.2692455469048438 * 90.3499984741211
# long position on XOM and short position on CVX
# gross daily return: -1.1%
# net daily return: -1.11%
# cumulative net return so far: -1.11%
# —————————next day—————————
# optimal slope: 19.68505665257024
# beta_stock1: 0.2624487761938529
# beta_stock2: 0.7464275668845572
# position_XOM: 0.7464275668845572
# times_ret1： -0.004924931695089008
# position_CVX: -0.2624487761938529
# times_ret2： -0.03459292173377304
# ===========
# day 2020-08-17 00:00:00
#
# old_signal: 0.75544709802406 →signal: 0.7464275668845572
# buy CVX: 0.00679677071099094 * 42.63999938964844  and sell XOM: 0.009019531139502712 * 42.63999938964844
# long position on CVX and short position on XOM
# gross daily return: 0.54%
# net daily return: 0.54%
# cumulative net return so far: 0.54%
# —————————next day—————————
# optimal slope: 16.526833663465922
# beta_stock1: 0.43063553873160626
# beta_stock2: 0.9535258931355381
# position_XOM: 0.9535258931355381
# times_ret1： -0.01107709680232527
# position_CVX: -0.43063553873160626
# times_ret2： -0.014150381178074989
# ===========
# day 2020-08-18 00:00:00
#
# old_signal: 0.7464275668845572 →signal: 0.9535258931355381
# buy XOM: 0.2070983262509809 * 42.43000030517578  and sell CVX: 0.1681867625377534 * 87.62999725341797
# long position on XOM and short position on CVX
# gross daily return: -0.45%
# net daily return: -0.45%
# cumulative net return so far: -0.45%
# —————————next day—————————
# optimal slope: 12.669090962142493
# beta_stock1: 0.4446049298429815
# beta_stock2: 0.9602224849100405
# position_XOM: 0.9602224849100405
# times_ret1： -0.015252607331091905
# position_CVX: -0.4446049298429815
# times_ret2： -0.018289175161679716
# ===========
# day 2020-08-19 00:00:00
#
# old_signal: 0.9535258931355381 →signal: 0.9602224849100405
# buy XOM: 0.006696591774502325 * 41.959999084472656  and sell CVX: 0.01396939111137524 * 86.38999938964844
# long position on XOM and short position on CVX
# gross daily return: -0.65%
# net daily return: -0.65%
# cumulative net return so far: -0.65%
# —————————next day—————————
# optimal slope: -8.080244493622809
# beta_stock1: 0.5867955864709247
# beta_stock2: 1.0224790999278273
# position_XOM: -1.0224790999278273
# times_ret1： -0.007502453426441957
# position_CVX: 0.5867955864709247
# times_ret2： 0.003183637309674525
# ===========
# day 2020-08-20 00:00:00
#
# old_signal: 0.9602224849100405 →signal: -1.0224790999278273
# buy CVX: 1.0314005163139062 * 41.31999969482422  and sell XOM: 1.9827015848378677 * 41.31999969482422
# long position on CVX and short position on XOM
# gross daily return: 0.95%
# net daily return: 0.92%
# cumulative net return so far: 0.92%
# —————————next day—————————
# optimal slope: -0.3876936939170964
# beta_stock1: 0.8231035358441918
# beta_stock2: 1.3456135084696734
# position_XOM: -1.3456135084696734
# times_ret1： 0.02950507068259456
# position_CVX: 0.8231035358441918
# times_ret2： 0.024917666567488173
# ===========
# day 2020-08-21 00:00:00
#
# old_signal: -1.0224790999278273 →signal: -1.3456135084696734
# buy CVX: 0.23630794937326716 * 41.0099983215332  and sell XOM: 0.32313440854184616 * 41.0099983215332
# long position on CVX and short position on XOM
# gross daily return: -1.92%
# net daily return: -1.92%
# cumulative net return so far: -1.92%
# —————————next day—————————
# optimal slope: 0.3217437463105492
# beta_stock1: 0.8691774730414549
# beta_stock2: 1.42660213593559
# position_XOM: -1.42660213593559
# times_ret1： -0.03173851524975335
# position_CVX: 0.8691774730414549
# times_ret2： -0.012270639131550909
# ===========
# day 2020-08-24 00:00:00
#
# old_signal: -1.3456135084696734 →signal: -1.42660213593559
# buy CVX: 0.04607393719726305 * 42.220001220703125  and sell XOM: 0.08098862746591662 * 42.220001220703125
# long position on CVX and short position on XOM
# gross daily return: 3.46%
# net daily return: 3.46%
# cumulative net return so far: 3.46%
# —————————next day—————————
# optimal slope: 0.24755712241208866
# beta_stock1: 1.0480841715045952
# beta_stock2: 1.5644544463505439
# position_XOM: -1.5644544463505439
# times_ret1： -0.021281867021784362
# position_CVX: 1.0480841715045952
# times_ret2： -0.01567396397504839
# ===========
# day 2020-08-25 00:00:00
#
# old_signal: -1.42660213593559 →signal: -1.5644544463505439
# buy CVX: 0.17890669846314033 * 40.880001068115234  and sell XOM: 0.13785231041495383 * 40.880001068115234
# long position on CVX and short position on XOM
# gross daily return: 1.69%
# net daily return: 1.68%
# cumulative net return so far: 1.68%
# —————————next day—————————
# optimal slope: 0.16753464816750235
# beta_stock1: 1.0394635735060995
# beta_stock2: 1.4802284076148657
# position_XOM: -1.4802284076148657
# times_ret1： -0.006748229302501518
# position_CVX: 1.0394635735060995
# times_ret2： 0.0015334381302709588
# ===========
# day 2020-08-26 00:00:00
#
# old_signal: -1.5644544463505439 →signal: -1.4802284076148657
# buy XOM: 0.08422603873567813 * 40.0099983215332  and sell CVX: 0.008620597998495683 * 84.77999877929688
# long position on XOM and short position on CVX
# gross daily return: 1.16%
# net daily return: 1.16%
# cumulative net return so far: 1.16%
# —————————next day—————————
# optimal slope: 0.32890842485356453
# beta_stock1: 0.634890905437614
# beta_stock2: 1.1873842247447075
# position_XOM: -1.1873842247447075
# times_ret1： 0.023905307199746373
# position_CVX: 0.634890905437614
# times_ret2： 0.008479490757929309
# ===========
# day 2020-08-27 00:00:00
#
# old_signal: -1.4802284076148657 →signal: -1.1873842247447075
# buy XOM: 0.29284418287015823 * 39.7400016784668  and sell CVX: 0.4045726680684856 * 84.91000366210938
# long position on XOM and short position on CVX
# gross daily return: -2.3%
# net daily return: -2.31%
# cumulative net return so far: -2.31%
# —————————next day—————————
# optimal slope: 0.34580485669965555
# beta_stock1: 0.014130272123657528
# beta_stock2: 0.6813446435478503
# position_XOM: -0.6813446435478503
# times_ret1： -0.01843204780812402
# position_CVX: 0.014130272123657528
# times_ret2： -0.019852820305612418
# ===========
# day 2020-08-28 00:00:00
#
# old_signal: -1.1873842247447075 →signal: -0.6813446435478503
# buy XOM: 0.5060395811968572 * 40.689998626708984  and sell CVX: 0.6207606333139564 * 85.62999725341797
# long position on XOM and short position on CVX
# gross daily return: 1.23%
# net daily return: 1.22%
# cumulative net return so far: 1.22%
# —————————next day—————————
# optimal slope: 0.4758803059244879
# beta_stock1: 0.12091963668772915
# beta_stock2: 0.9809351001805646
# position_XOM: -0.9809351001805646
# times_ret1： -0.012769112144940142
# position_CVX: 0.12091963668772915
# times_ret2： -0.01012746897450778
# ===========
# day 2020-08-31 00:00:00
#
# old_signal: -0.6813446435478503 →signal: -0.9809351001805646
# buy CVX: 0.10678936456407162 * 39.939998626708984  and sell XOM: 0.29959045663271433 * 39.939998626708984
# long position on CVX and short position on XOM
# gross daily return: 1.13%
# net daily return: 1.13%
# cumulative net return so far: 1.13%
# —————————next day—————————
# optimal slope: 0.7922186691294615
# beta_stock1: 0.24566966215803535
# beta_stock2: 1.0952646110656237
# position_XOM: -1.0952646110656237
# times_ret1： -0.006086778508984536
# position_CVX: 0.24566966215803535
# times_ret2： 0.0013240323534808862
# ===========
# day 2020-09-01 00:00:00
#
# old_signal: -0.9809351001805646 →signal: -1.0952646110656237
# buy CVX: 0.1247500254703062 * 39.43000030517578  and sell XOM: 0.11432951088505905 * 39.43000030517578
# long position on CVX and short position on XOM
# gross daily return: 0.7%
# net daily return: 0.7%
# cumulative net return so far: 0.7%
# —————————next day—————————
# optimal slope: 1.0016442369711362
# beta_stock1: 0.13135900082609997
# beta_stock2: 0.9616640368687689
# position_XOM: -0.9616640368687689
# times_ret1： -0.0020412865312758877
# position_CVX: 0.13135900082609997
# times_ret2： -0.010938858461391754
# ===========
# day 2020-09-02 00:00:00
#
# old_signal: -1.0952646110656237 →signal: -0.9616640368687689
# buy XOM: 0.13360057419685478 * 39.189998626708984  and sell CVX: 0.11431066133193538 * 83.19000244140625
# long position on XOM and short position on CVX
# gross daily return: 0.05%
# net daily return: 0.05%
# cumulative net return so far: 0.05%
# —————————next day—————————
# optimal slope: 1.1389307074608856
# beta_stock1: 0.027708855579265668
# beta_stock2: 0.7887572830134562
# position_XOM: -0.7887572830134562
# times_ret1： -0.0007670360222120642
# position_CVX: 0.027708855579265668
# times_ret2： -0.004253749140904928
# ===========
# day 2020-09-03 00:00:00
#
# old_signal: -0.9616640368687689 →signal: -0.7887572830134562
# buy XOM: 0.17290675385531273 * 39.11000061035156  and sell CVX: 0.1036501452468343 * 82.27999877929688
# long position on XOM and short position on CVX
# gross daily return: 0.05%
# net daily return: 0.05%
# cumulative net return so far: 0.05%
# —————————next day—————————
# optimal slope: 1.2842608156663173
# beta_stock1: -0.059347683700183534
# beta_stock2: 0.3758471744497041
# position_XOM: -0.3758471744497041
# times_ret1： -0.023029720668122478
# position_CVX: -0.059347683700183534
# times_ret2： -0.03612839098556264
# ===========
# day 2020-09-04 00:00:00
#
# old_signal: -0.7887572830134562 →signal: -0.3758471744497041
# buy XOM: 0.41291010856375204 * 39.08000183105469  and sell CVX: 0.0870565392794492 * 81.93000030517578
# long position on XOM and short position on CVX
# gross daily return: 1.08%
# net daily return: 1.07%
# cumulative net return so far: 1.07%
# —————————next day—————————
# optimal slope: 1.412417837948499
# beta_stock1: -0.07685831374250021
# beta_stock2: 0.36447777865914677
# position_XOM: -0.36447777865914677
# times_ret1： -0.0060240843477716854
# position_CVX: -0.07685831374250021
# times_ret2： 0.01342278766884264
# ===========
# day 2020-09-08 00:00:00
#
# old_signal: -0.3758471744497041 →signal: -0.36447777865914677
# buy XOM: 0.011369395790557346 * 38.18000030517578  and sell CVX: 0.017510630042316677 * 78.97000122070312
# long position on XOM and short position on CVX
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: 0.12%
# —————————next day—————————
# optimal slope: 1.6112063094833045
# beta_stock1: 0.07858325287583112
# beta_stock2: 0.5440396257476257
# position_XOM: -0.5440396257476257
# times_ret1： -0.025032957676965006
# position_CVX: 0.07858325287583112
# times_ret2： -0.023491156842355365
# ===========
# day 2020-09-09 00:00:00
#
# old_signal: -0.36447777865914677 →signal: -0.5440396257476257
# buy CVX: 0.15544156661833133 * 37.95000076293945  and sell XOM: 0.1795618470884789 * 37.95000076293945
# long position on CVX and short position on XOM
# gross daily return: 1.18%
# net daily return: 1.17%
# cumulative net return so far: 1.17%
# —————————next day—————————
# optimal slope: 1.7086185739440567
# beta_stock1: 0.1286518990433962
# beta_stock2: 0.6175818827243724
# position_XOM: -0.6175818827243724
# times_ret1： -0.0027026614627322365
# position_CVX: 0.1286518990433962
# times_ret2： -0.005886104612810916
# ===========
# day 2020-09-10 00:00:00
#
# old_signal: -0.5440396257476257 →signal: -0.6175818827243724
# buy CVX: 0.05006864616756507 * 37.0  and sell XOM: 0.07354225697674677 * 37.0
# long position on CVX and short position on XOM
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: 0.09%
# —————————next day—————————
# optimal slope: 1.8533816933261713
# beta_stock1: 0.25377040752268165
# beta_stock2: 0.6091654302736182
# position_XOM: -0.6091654302736182
# times_ret1： -0.006504110258599205
# position_CVX: 0.25377040752268165
# times_ret2： -0.005148687261022911
# ===========
# day 2020-09-11 00:00:00
#
# old_signal: -0.6175818827243724 →signal: -0.6091654302736182
# buy XOM: 0.008416452450754175 * 36.900001525878906  and sell CVX: 0.12511850847928546 * 77.69000244140625
# long position on XOM and short position on CVX
# gross daily return: 0.27%
# net daily return: 0.26%
# cumulative net return so far: 0.26%
# —————————next day—————————
# optimal slope: 1.9042348576867674
# beta_stock1: 0.24894333327715862
# beta_stock2: 0.6087862311915716
# position_XOM: -0.6087862311915716
# times_ret1： -0.01063828126764077
# position_CVX: 0.24894333327715862
# times_ret2： -0.012162018764026228
# ===========
# day 2020-09-14 00:00:00
#
# old_signal: -0.6091654302736182 →signal: -0.6087862311915716
# buy XOM: 0.000379199082046644 * 36.65999984741211  and sell CVX: 0.004827074245523033 * 77.29000091552734
# long position on XOM and short position on CVX
# gross daily return: 0.34%
# net daily return: 0.34%
# cumulative net return so far: 0.34%
# —————————next day—————————
# optimal slope: 1.9086456607215343
# beta_stock1: 0.24284397553054676
# beta_stock2: 0.5899667675881726
# position_XOM: -0.5899667675881726
# times_ret1： 0.042459357488033866
# position_CVX: 0.24284397553054676
# times_ret2： 0.028945633642962543
# ===========
# day 2020-09-15 00:00:00
#
# old_signal: -0.6087862311915716 →signal: -0.5899667675881726
# buy XOM: 0.018819463603399034 * 36.27000045776367  and sell CVX: 0.006099357746611855 * 76.3499984741211
# long position on XOM and short position on CVX
# gross daily return: -1.8%
# net daily return: -1.8%
# cumulative net return so far: -1.8%
# —————————next day—————————
# optimal slope: 1.914329189643673
# beta_stock1: 0.241590099353662
# beta_stock2: 0.5725053233703301
# position_XOM: -0.5725053233703301
# times_ret1： -0.00026453678569648975
# position_CVX: 0.241590099353662
# times_ret2： 0.0029277413961481535
# ===========
# day 2020-09-16 00:00:00
#
# old_signal: -0.5899667675881726 →signal: -0.5725053233703301
# buy XOM: 0.01746144421784246 * 37.810001373291016  and sell CVX: 0.0012538761768847717 * 78.55999755859375
# long position on XOM and short position on CVX
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: 0.09%
# —————————next day—————————
# optimal slope: 1.8945615815046324
# beta_stock1: 0.17927692668583992
# beta_stock2: 0.5432441009087361
# position_XOM: -0.5432441009087361
# times_ret1： -0.016137582610147083
# position_CVX: 0.17927692668583992
# times_ret2： -0.007361363425753997
# ===========
# day 2020-09-17 00:00:00
#
# old_signal: -0.5725053233703301 →signal: -0.5432441009087361
# buy XOM: 0.029261222461594016 * 37.79999923706055  and sell CVX: 0.062313172667822075 * 78.79000091552734
# long position on XOM and short position on CVX
# gross daily return: 0.74%
# net daily return: 0.74%
# cumulative net return so far: 0.74%
# —————————next day—————————
# optimal slope: 1.9698668095065055
# beta_stock1: 0.15896101009831953
# beta_stock2: 0.5081637468517992
# position_XOM: 0.0
# times_ret1： -0.02043555659040519
# position_CVX: -0.0
# times_ret2： -0.02442137904453756
# ===========
# day 2020-09-18 00:00:00
#
# old_signal: -0.5432441009087361 →signal: 0.0
# buy XOM: 0.5432441009087361 * 37.189998626708984  and sell CVX: 0.17927692668583992 * 78.20999908447266
# long position on XOM and short position on CVX
# gross daily return: 0.0%
# net daily return: -0.01%
# cumulative net return so far: -0.01%
# —————————next day—————————
# optimal slope: 2.0387415283248114
# beta_stock1: 0.19515652806434264
# beta_stock2: 0.5176917624147049
# position_XOM: 0.0
# times_ret1： -0.024704955211077517
# position_CVX: -0.0
# times_ret2： -0.010091798711182376
# ===========
# day 2020-09-21 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.1402694927698716
# beta_stock1: 0.2325568336904222
# beta_stock2: 0.5494166967278988
# position_XOM: 0.0
# times_ret1： -0.032085545421203565
# position_CVX: -0.0
# times_ret2： -0.0473984097565745
# ===========
# day 2020-09-22 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.155908221991727
# beta_stock1: 0.06917546447617225
# beta_stock2: 0.4447672878122074
# position_XOM: 0.0
# times_ret1： -0.002035466591060464
# position_CVX: -0.0
# times_ret2： -0.0020846963564470355
# ===========
# day 2020-09-23 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.2406099690639243
# beta_stock1: 0.2162070664931101
# beta_stock2: 0.612124541356296
# position_XOM: 0.0
# times_ret1： 0.009324000514850717
# position_CVX: -0.0
# times_ret2： 0.0004178102788554572
# ===========
# day 2020-09-24 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.2411338297940886
# beta_stock1: 0.2753220827857841
# beta_stock2: 0.6650193165374125
# position_XOM: 0.0
# times_ret1： 0.019341858990990612
# position_CVX: -0.0
# times_ret2： 0.02923567340371669
# ===========
# day 2020-09-25 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.246017962601572
# beta_stock1: 0.3233799594892145
# beta_stock2: 0.6426571617610368
# position_XOM: 0.0
# times_ret1： -0.029170279069239857
# position_CVX: -0.0
# times_ret2： -0.02745838997588579
# ===========
# day 2020-09-28 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.195330896103811
# beta_stock1: 0.34738953124727723
# beta_stock2: 0.7163128828835146
# position_XOM: 0.0
# times_ret1： 0.0014586655057879927
# position_CVX: -0.0
# times_ret2： 0.0013907993323909462
# ===========
# day 2020-09-29 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.191212785202671
# beta_stock1: 0.35860831907539215
# beta_stock2: 0.7261965008440354
# position_XOM: 0.0
# times_ret1： -0.03495487034474731
# position_CVX: -0.0
# times_ret2： -0.021944469875759598
# ===========
# day 2020-09-30 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.1897154258688483
# beta_stock1: 0.38838192120089243
# beta_stock2: 0.7491762063720214
# position_XOM: 0.0
# times_ret1： -0.004527664384027741
# position_CVX: -0.0
# times_ret2： 0.010934454593617193
# ===========
# day 2020-10-01 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.132955377591376
# beta_stock1: 0.3538901088531971
# beta_stock2: 0.7295434043123716
# position_XOM: 0.7295434043123716
# times_ret1： 0.02304433434746289
# position_CVX: -0.3538901088531971
# times_ret2： 0.02121076633026875
# ===========
# day 2020-10-02 00:00:00
#
# old_signal: 0.0 →signal: 0.7295434043123716
# buy XOM: 0.7295434043123716 * 32.97999954223633  and sell CVX: 0.3538901088531971 * 71.19000244140625
# long position on XOM and short position on CVX
# gross daily return: 0.93%
# net daily return: 0.92%
# cumulative net return so far: 0.92%
# —————————next day—————————
# optimal slope: 2.0088920678759083
# beta_stock1: 0.5217030882246636
# beta_stock2: 0.8911188504169192
# position_XOM: 0.8911188504169192
# times_ret1： -0.01037351130429065
# position_CVX: -0.5217030882246636
# times_ret2： -0.005501979549863645
# ===========
# day 2020-10-05 00:00:00
#
# old_signal: 0.7295434043123716 →signal: 0.8911188504169192
# buy XOM: 0.16157544610454755 * 33.7400016784668  and sell CVX: 0.1678129793714665 * 72.69999694824219
# long position on XOM and short position on CVX
# gross daily return: -0.64%
# net daily return: -0.64%
# cumulative net return so far: -0.64%
# —————————next day—————————
# optimal slope: 1.917723602210692
# beta_stock1: 0.6456986509788198
# beta_stock2: 0.9619989572491905
# position_XOM: 0.9619989572491905
# times_ret1： 0.003294417860506549
# position_CVX: -0.6456986509788198
# times_ret2： 0.020470202836361917
# ===========
# day 2020-10-06 00:00:00
#
# old_signal: 0.8911188504169192 →signal: 0.9619989572491905
# buy XOM: 0.0708801068322713 * 33.38999938964844  and sell CVX: 0.12399556275415624 * 72.30000305175781
# long position on XOM and short position on CVX
# gross daily return: -1.0%
# net daily return: -1.01%
# cumulative net return so far: -1.01%
# —————————next day—————————
# optimal slope: 1.8211981685027212
# beta_stock1: 0.6382122631560023
# beta_stock2: 0.8604546406414002
# position_XOM: 0.8604546406414002
# times_ret1： 0.05253726332934927
# position_CVX: -0.6382122631560023
# times_ret2： 0.019517517826393993
# ===========
# day 2020-10-07 00:00:00
#
# old_signal: 0.9619989572491905 →signal: 0.8604546406414002
# buy CVX: 0.00748638782281752 * 33.5  and sell XOM: 0.10154431660779029 * 33.5
# long position on CVX and short position on XOM
# gross daily return: 3.27%
# net daily return: 3.27%
# cumulative net return so far: 3.27%
# —————————next day—————————
# optimal slope: 1.7160178976849783
# beta_stock1: 0.7084397844549407
# beta_stock2: 0.9091792779551788
# position_XOM: 0.9091792779551788
# times_ret1： -0.014747494833227126
# position_CVX: -0.7084397844549407
# times_ret2： -0.016219106632603175
# ===========
# day 2020-10-08 00:00:00
#
# old_signal: 0.8604546406414002 →signal: 0.9091792779551788
# buy XOM: 0.04872463731377863 * 35.2599983215332  and sell CVX: 0.07022752129893839 * 75.22000122070312
# long position on XOM and short position on CVX
# gross daily return: -0.19%
# net daily return: -0.19%
# cumulative net return so far: -0.19%
# —————————next day—————————
# optimal slope: 1.6153596141188273
# beta_stock1: 0.7813784122677199
# beta_stock2: 0.9238946256217431
# position_XOM: 0.9238946256217431
# times_ret1： -0.0031663962301919923
# position_CVX: -0.7813784122677199
# times_ret2： 0.006891920759871217
# ===========
# day 2020-10-09 00:00:00
#
# old_signal: 0.9091792779551788 →signal: 0.9238946256217431
# buy XOM: 0.014715347666564238 * 34.7400016784668  and sell CVX: 0.07293862781277916 * 74.0
# long position on XOM and short position on CVX
# gross daily return: -0.83%
# net daily return: -0.83%
# cumulative net return so far: -0.83%
# —————————next day—————————
# optimal slope: 1.5316623043511417
# beta_stock1: 0.738714777310092
# beta_stock2: 0.872001287377554
# position_XOM: 0.872001287377554
# times_ret1： -0.011839440796021394
# position_CVX: -0.738714777310092
# times_ret2： -0.014897336981981146
# ===========
# day 2020-10-12 00:00:00
#
# old_signal: 0.9238946256217431 →signal: 0.872001287377554
# buy CVX: 0.042663634957627816 * 34.630001068115234  and sell XOM: 0.05189333824418907 * 34.630001068115234
# long position on CVX and short position on XOM
# gross daily return: 0.07%
# net daily return: 0.07%
# cumulative net return so far: 0.07%
# —————————next day—————————
# optimal slope: 1.402258245234709
# beta_stock1: 0.7286212186313848
# beta_stock2: 0.9003879970055132
# position_XOM: 0.9003879970055132
# times_ret1： -0.0020455783847801445
# position_CVX: -0.7286212186313848
# times_ret2： -0.0061308524289070965
# ===========
# day 2020-10-13 00:00:00
#
# old_signal: 0.872001287377554 →signal: 0.9003879970055132
# buy XOM: 0.028386709627959195 * 34.220001220703125  and sell CVX: 0.010093558678707204 * 73.4000015258789
# long position on XOM and short position on CVX
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: 0.26%
# —————————next day—————————
# optimal slope: 1.2841020425359266
# beta_stock1: 0.7480115312757938
# beta_stock2: 0.9310006679333667
# position_XOM: 0.0
# times_ret1： 0.008784750326678914
# position_CVX: -0.0
# times_ret2： 0.00767656218526791
# ===========
# day 2020-10-14 00:00:00
#
# old_signal: 0.9003879970055132 →signal: 0.0
# buy CVX: 0.7286212186313848 * 34.150001525878906  and sell XOM: 0.9003879970055132 * 34.150001525878906
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# optimal slope: 1.207278006474653
# beta_stock1: 0.8264401686516571
# beta_stock2: 0.9939988536664762
# position_XOM: 0.0
# times_ret1： -0.010159717882935015
# position_CVX: -0.0
# times_ret2： -0.008434263754108273
# ===========
# day 2020-10-15 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.0222856269988925
# beta_stock1: 0.8543755017338094
# beta_stock2: 1.0362766155473395
# position_XOM: 0.0
# times_ret1： -0.019941358815363075
# position_CVX: -0.0
# times_ret2： -0.022088086484196245
# ===========
# day 2020-10-16 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 0.6437850347428642
# beta_stock1: 0.8557759106420328
# beta_stock2: 1.0876683548196953
# position_XOM: 0.0
# times_ret1： 0.008378294713801804
# position_CVX: -0.0
# times_ret2： 0.005611693781272686
# ===========
# day 2020-10-19 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 0.04538406655042681
# beta_stock1: 0.8326584451365014
# beta_stock2: 1.047732127226573
# position_XOM: 0.0
# times_ret1： -0.01602376567662256
# position_CVX: -0.0
# times_ret2： -0.011300189106378422
# ===========
# day 2020-10-20 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: -0.9802884799076762
# beta_stock1: 0.9276205951293193
# beta_stock2: 1.1007503362405586
# position_XOM: -1.1007503362405586
# times_ret1： 0.05126660949222317
# position_CVX: 0.9276205951293193
# times_ret2： 0.035699148881702225
# ===========
# day 2020-10-21 00:00:00
#
# old_signal: 0.0 →signal: -1.1007503362405586
# buy CVX: 0.9276205951293193 * 33.15999984741211  and sell XOM: 1.1007503362405586 * 33.15999984741211
# long position on CVX and short position on XOM
# gross daily return: -2.33%
# net daily return: -2.35%
# cumulative net return so far: -2.35%
# —————————next day—————————
# optimal slope: -2.6479382652955925
# beta_stock1: 0.8735819257181596
# beta_stock2: 0.8794491888370624
# position_XOM: 0.8794491888370624
# times_ret1： -0.02008034281937421
# position_CVX: -0.8735819257181596
# times_ret2： -0.01130792661853075
# ===========
# day 2020-10-22 00:00:00
#
# old_signal: -1.1007503362405586 →signal: 0.8794491888370624
# buy XOM: 1.980199525077621 * 34.86000061035156  and sell CVX: 1.801202520847479 * 73.4000015258789
# long position on XOM and short position on CVX
# gross daily return: -0.78%
# net daily return: -0.82%
# cumulative net return so far: -0.82%
# —————————next day—————————
# optimal slope: -5.481444485379489
# beta_stock1: 0.9226616337518786
# beta_stock2: 0.9129717825783922
# position_XOM: 0.9129717825783922
# times_ret1： -0.023711984101556727
# position_CVX: -0.9226616337518786
# times_ret2： -0.022461034315454542
# ===========
# day 2020-10-23 00:00:00
#
# old_signal: 0.8794491888370624 →signal: 0.9129717825783922
# buy XOM: 0.03352259374132982 * 34.15999984741211  and sell CVX: 0.04907970803371897 * 72.56999969482422
# long position on XOM and short position on CVX
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: -0.09%
# —————————next day—————————
# optimal slope: -9.462508163634713
# beta_stock1: 0.931929395609684
# beta_stock2: 0.9879193731698304
# position_XOM: -0.9879193731698304
# times_ret1： -0.015892018097336424
# position_CVX: 0.931929395609684
# times_ret2： -0.02015788350665626
# ===========
# day 2020-10-26 00:00:00
#
# old_signal: 0.9129717825783922 →signal: -0.9879193731698304
# buy CVX: 1.8545910293615626 * 33.349998474121094  and sell XOM: 1.9008911557482224 * 33.349998474121094
# long position on CVX and short position on XOM
# gross daily return: -0.31%
# net daily return: -0.35%
# cumulative net return so far: -0.35%
# —————————next day—————————
# optimal slope: 7.331373364163797
# beta_stock1: 0.9115037786991266
# beta_stock2: 0.9057404405052911
# position_XOM: 0.9057404405052911
# times_ret1： -0.03808653295621833
# position_CVX: -0.9115037786991266
# times_ret2： -0.037836351632647536
# ===========
# day 2020-10-27 00:00:00
#
# old_signal: -0.9879193731698304 →signal: 0.9057404405052911
# buy XOM: 1.8936598136751215 * 32.81999969482422  and sell CVX: 1.8434331743088106 * 69.51000213623047
# long position on XOM and short position on CVX
# gross daily return: -0.0%
# net daily return: -0.04%
# cumulative net return so far: -0.04%
# —————————next day—————————
# optimal slope: 4.028803908577168
# beta_stock1: 0.8719901765588025
# beta_stock2: 0.877824597124768
# position_XOM: 0.877824597124768
# times_ret1： 0.04434594676630388
# position_CVX: -0.8719901765588025
# times_ret2： 0.02870822184792665
# ===========
# day 2020-10-28 00:00:00
#
# old_signal: 0.9057404405052911 →signal: 0.877824597124768
# buy CVX: 0.03951360214032407 * 31.56999969482422  and sell XOM: 0.02791584338052311 * 31.56999969482422
# long position on CVX and short position on XOM
# gross daily return: 1.39%
# net daily return: 1.39%
# cumulative net return so far: 1.39%
# —————————next day—————————
# optimal slope: 3.292090032479196
# beta_stock1: 0.9267582374647323
# beta_stock2: 0.9355685542277424
# position_XOM: 0.0
# times_ret1： -0.010615780280850529
# position_CVX: -0.0
# times_ret2： 0.01017437379640218
# ===========
# day 2020-10-29 00:00:00
#
# old_signal: 0.877824597124768 →signal: 0.0
# buy CVX: 0.8719901765588025 * 32.970001220703125  and sell XOM: 0.877824597124768 * 32.970001220703125
# long position on CVX and short position on XOM
# gross daily return: -0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# optimal slope: 3.845105350094406
# beta_stock1: 1.1219077551595973
# beta_stock2: 1.051204282532277
# position_XOM: 1.051204282532277
# times_ret1： 0.0419988593329752
# position_CVX: -1.1219077551595973
# times_ret2： 0.03812951835796996
# ===========
# day 2020-10-30 00:00:00
#
# old_signal: 0.0 →signal: 1.051204282532277
# buy XOM: 1.051204282532277 * 32.619998931884766  and sell CVX: 1.1219077551595973 * 69.5
# long position on XOM and short position on CVX
# gross daily return: 0.14%
# net daily return: 0.12%
# cumulative net return so far: 0.12%
# —————————next day—————————
# optimal slope: 3.4526780568772404
# beta_stock1: 1.1278418898281721
# beta_stock2: 1.0297760681176562
# position_XOM: 0.0
# times_ret1： -0.017063895334319068
# position_CVX: -0.0
# times_ret2： -0.00568265631931153
# ===========
# day 2020-11-02 00:00:00
#
# old_signal: 1.051204282532277 →signal: 0.0
# buy CVX: 1.1219077551595973 * 33.9900016784668  and sell XOM: 1.051204282532277 * 33.9900016784668
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# optimal slope: 3.297686602640437
# beta_stock1: 1.2208127897105125
# beta_stock2: 1.11224103727965
# position_XOM: 0.0
# times_ret1： -0.00538761765931961
# position_CVX: -0.0
# times_ret2： 0.000418159746168989
# ===========
# day 2020-11-03 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 3.0676744029735143
# beta_stock1: 1.0415202118330003
# beta_stock2: 1.0198295126685348
# position_XOM: 0.0
# times_ret1： -0.001805638703508028
# position_CVX: -0.0
# times_ret2： 0.005155395902025184
# ===========
# day 2020-11-04 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.7289054478590264
# beta_stock1: 0.948477155166294
# beta_stock2: 0.8858705221511419
# position_XOM: 0.8858705221511419
# times_ret1： -0.011757594548605255
# position_CVX: -0.948477155166294
# times_ret2： -0.013723286278702007
# ===========
# day 2020-11-05 00:00:00
#
# old_signal: 0.0 →signal: 0.8858705221511419
# buy XOM: 0.8858705221511419 * 33.16999816894531  and sell CVX: 0.948477155166294 * 72.13999938964844
# long position on XOM and short position on CVX
# gross daily return: 0.26%
# net daily return: 0.24%
# cumulative net return so far: 0.24%
# —————————next day—————————
# optimal slope: 2.228553667071516
# beta_stock1: 0.7859351179905787
# beta_stock2: 0.8160428005790367
# position_XOM: 0.8160428005790367
# times_ret1： 0.12660163759676402
# position_CVX: -0.7859351179905787
# times_ret2： 0.11595221114646481
# ===========
# day 2020-11-06 00:00:00
#
# old_signal: 0.8858705221511419 →signal: 0.8160428005790367
# buy CVX: 0.16254203717571536 * 32.779998779296875  and sell XOM: 0.06982772157210526 * 32.779998779296875
# long position on CVX and short position on XOM
# gross daily return: 1.22%
# net daily return: 1.22%
# cumulative net return so far: 1.22%
# —————————next day—————————
# optimal slope: 2.0141893478608015
# beta_stock1: 0.824818281500107
# beta_stock2: 0.8613110584762343
# position_XOM: 0.8613110584762343
# times_ret1： -0.001895469651929771
# position_CVX: -0.824818281500107
# times_ret2： 0.04622163851910188
# ===========
# day 2020-11-09 00:00:00
#
# old_signal: 0.8160428005790367 →signal: 0.8613110584762343
# buy XOM: 0.04526825789719768 * 36.93000030517578  and sell CVX: 0.03888316350952836 * 79.4000015258789
# long position on XOM and short position on CVX
# gross daily return: -3.98%
# net daily return: -3.98%
# cumulative net return so far: -3.98%
# —————————next day—————————
# optimal slope: 4.311391500697198
# beta_stock1: 1.1954413117863447
# beta_stock2: 1.1673483740160289
# position_XOM: -1.1673483740160289
# times_ret1： -0.010309307157431724
# position_CVX: 1.1954413117863447
# times_ret2： -0.0073432119007166285
# ===========
# day 2020-11-10 00:00:00
#
# old_signal: 0.8613110584762343 →signal: -1.1673483740160289
# buy CVX: 2.0202595932864518 * 36.86000061035156  and sell XOM: 2.028659432492263 * 36.86000061035156
# long position on CVX and short position on XOM
# gross daily return: 0.33%
# net daily return: 0.29%
# cumulative net return so far: 0.29%
# —————————next day—————————
# optimal slope: 4.25837646533152
# beta_stock1: 1.1845763823287645
# beta_stock2: 1.1288825562559897
# position_XOM: -1.1288825562559897
# times_ret1： -0.03426535130716646
# position_CVX: 1.1845763823287645
# times_ret2： -0.021707505886504497
# ===========
# day 2020-11-11 00:00:00
#
# old_signal: -1.1673483740160289 →signal: -1.1288825562559897
# buy XOM: 0.03846581776003921 * 36.47999954223633  and sell CVX: 0.010864929457580219 * 82.45999908447266
# long position on XOM and short position on CVX
# gross daily return: 1.3%
# net daily return: 1.3%
# cumulative net return so far: 1.3%
# —————————next day—————————
# optimal slope: 3.9749303790623793
# beta_stock1: 1.1532602117190098
# beta_stock2: 1.0846025806281314
# position_XOM: 1.0846025806281314
# times_ret1： 0.024127229629943958
# position_CVX: -1.1532602117190098
# times_ret2： 0.02925499769330675
# ===========
# day 2020-11-12 00:00:00
#
# old_signal: -1.1288825562559897 →signal: 1.0846025806281314
# buy XOM: 2.2134851368841213 * 35.22999954223633  and sell CVX: 2.3378365940477743 * 80.66999816894531
# long position on XOM and short position on CVX
# gross daily return: -0.76%
# net daily return: -0.8%
# cumulative net return so far: -0.8%
# —————————next day—————————
# optimal slope: 4.187176914600132
# beta_stock1: 1.2279090706038682
# beta_stock2: 1.1304527429010187
# position_XOM: 1.1304527429010187
# times_ret1： 0.05764960950104858
# position_CVX: -1.2279090706038682
# times_ret2： 0.0714199734115184
# ===========
# day 2020-11-13 00:00:00
#
# old_signal: 1.0846025806281314 →signal: 1.1304527429010187
# buy XOM: 0.045850162272887296 * 36.08000183105469  and sell CVX: 0.0746488588848584 * 83.02999877929688
# long position on XOM and short position on CVX
# gross daily return: -2.25%
# net daily return: -2.25%
# cumulative net return so far: -2.25%
# —————————next day—————————
# optimal slope: 4.159893280098269
# beta_stock1: 1.2469757011705154
# beta_stock2: 1.1563424638242144
# position_XOM: 0.0
# times_ret1： 0.01336473594267562
# position_CVX: -0.0
# times_ret2： -0.021582713452168112
# ===========
# day 2020-11-16 00:00:00
#
# old_signal: 1.1304527429010187 →signal: 0.0
# buy CVX: 1.2279090706038682 * 38.15999984741211  and sell XOM: 1.1304527429010187 * 38.15999984741211
# long position on CVX and short position on XOM
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# optimal slope: 3.9971412268277016
# beta_stock1: 1.3375750102799324
# beta_stock2: 1.2294976699067983
# position_XOM: -1.2294976699067983
# times_ret1： -0.03775534402908598
# position_CVX: 1.3375750102799324
# times_ret2： -0.031709583033082245
# ===========
# day 2020-11-17 00:00:00
#
# old_signal: 0.0 →signal: -1.2294976699067983
# buy CVX: 1.3375750102799324 * 38.66999816894531  and sell XOM: 1.2294976699067983 * 38.66999816894531
# long position on CVX and short position on XOM
# gross daily return: 0.4%
# net daily return: 0.37%
# cumulative net return so far: 0.37%
# —————————next day—————————
# optimal slope: 3.7373640806121498
# beta_stock1: 1.3058271869751734
# beta_stock2: 1.2767225838548057
# position_XOM: -1.2767225838548057
# times_ret1： 0.005106219996805494
# position_CVX: 1.3058271869751734
# times_ret2： 0.01720461080491753
# ===========
# day 2020-11-18 00:00:00
#
# old_signal: -1.2294976699067983 →signal: -1.2767225838548057
# buy CVX: -0.031747823304759004 * 37.209999084472656  and sell XOM: 0.04722491394800743 * 37.209999084472656
# long position on CVX and short position on XOM
# gross daily return: 1.59%
# net daily return: 1.59%
# cumulative net return so far: 1.59%
# —————————next day—————————
# optimal slope: 3.6589089973081252
# beta_stock1: 1.3804481875750056
# beta_stock2: 1.3424282347665089
# position_XOM: -1.3424282347665089
# times_ret1： -0.012299542256746232
# position_CVX: 1.3804481875750056
# times_ret2： 0.0006998431849343234
# ===========
# day 2020-11-19 00:00:00
#
# old_signal: -1.2767225838548057 →signal: -1.3424282347665089
# buy CVX: 0.07462100059983223 * 37.400001525878906  and sell XOM: 0.0657056509117031 * 37.400001525878906
# long position on CVX and short position on XOM
# gross daily return: 1.75%
# net daily return: 1.75%
# cumulative net return so far: 1.75%
# —————————next day—————————
# optimal slope: 3.6666772618737458
# ...
# long position on XOM and short position on CVX
# gross daily return: -2.32%
# net daily return: -2.35%
# cumulative net return so far: -2.35%
# —————————next day—————————
# optimal slope: 12.96192935481405
# beta_stock1: 1.9520691898817808
# beta_stock2: 1.597194012258457
# position_XOM: 1.597194012258457
# times_ret1： -0.010113304826313896
# position_CVX: -1.9520691898817808
# times_ret2： -0.006625100440563303
# ===========
# day 2021-08-12 00:00:00
#
# old_signal: 1.5843280151818573 →signal: 1.597194012258457
# buy XOM: 0.012865997076599633 * 57.349998474121094  and sell CVX: 0.011942443887029697 * 102.63999938964844
# long position on XOM and short position on CVX
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: -0.32%
# —————————next day—————————
# optimal slope: 6.697098080068266
# beta_stock1: 1.8726250843371486
# beta_stock2: 1.5692462985128675
# position_XOM: 1.5692462985128675
# times_ret1： -0.014620430233609039
# position_CVX: -1.8726250843371486
# times_ret2： -0.010200087533011049
# ===========
# day 2021-08-13 00:00:00
#
# old_signal: 1.597194012258457 →signal: 1.5692462985128675
# buy CVX: 0.07944410554463222 * 56.77000045776367  and sell XOM: 0.027947713745589464 * 56.77000045776367
# long position on CVX and short position on XOM
# gross daily return: -0.38%
# net daily return: -0.39%
# cumulative net return so far: -0.39%
# —————————next day—————————
# optimal slope: 6.172122612195404
# beta_stock1: 1.7557712188275274
# beta_stock2: 1.4144187032596611
# position_XOM: 1.4144187032596611
# times_ret1： -0.006792943560004594
# position_CVX: -1.7557712188275274
# times_ret2： -0.0018826279771989585
# ===========
# day 2021-08-16 00:00:00
#
# old_signal: 1.5692462985128675 →signal: 1.4144187032596611
# buy CVX: 0.11685386550962118 * 55.939998626708984  and sell XOM: 0.15482759525320633 * 55.939998626708984
# long position on CVX and short position on XOM
# gross daily return: -0.63%
# net daily return: -0.63%
# cumulative net return so far: -0.63%
# —————————next day—————————
# optimal slope: 13.680497779224762
# beta_stock1: 1.608761429793728
# beta_stock2: 1.2547512547082642
# position_XOM: 1.2547512547082642
# times_ret1： -0.021058350516978686
# position_CVX: -1.608761429793728
# times_ret2： -0.04000800431239149
# ===========
# day 2021-08-17 00:00:00
#
# old_signal: 1.4144187032596611 →signal: 1.2547512547082642
# buy CVX: 0.14700978903379935 * 55.560001373291016  and sell XOM: 0.15966744855139692 * 55.560001373291016
# long position on CVX and short position on XOM
# gross daily return: 3.79%
# net daily return: 3.79%
# cumulative net return so far: 3.79%
# —————————next day—————————
# optimal slope: -3.97288466517666
# beta_stock1: 1.7482518851920492
# beta_stock2: 1.4886788073936015
# position_XOM: -1.4886788073936015
# times_ret1： -0.03052031377165343
# position_CVX: 1.7482518851920492
# times_ret2： -0.02492240029753856
# ===========
# day 2021-08-18 00:00:00
#
# old_signal: 1.2547512547082642 →signal: -1.4886788073936015
# buy CVX: 3.3570133149857773 * 54.38999938964844  and sell XOM: 2.743430062101866 * 54.38999938964844
# long position on CVX and short position on XOM
# gross daily return: 0.19%
# net daily return: 0.13%
# cumulative net return so far: 0.13%
# —————————next day—————————
# optimal slope: -0.3517434511923806
# beta_stock1: 1.4354529898195523
# beta_stock2: 1.7412139203902073
# position_XOM: -1.7412139203902073
# times_ret1： 0.00018968587743795062
# position_CVX: 1.4354529898195523
# times_ret2： 0.0001060784402731052
# ===========
# day 2021-08-19 00:00:00
#
# old_signal: -1.4886788073936015 →signal: -1.7412139203902073
# buy CVX: -0.31279889537249694 * 52.72999954223633  and sell XOM: 0.2525351129966058 * 52.72999954223633
# long position on CVX and short position on XOM
# gross daily return: -0.02%
# net daily return: -0.02%
# cumulative net return so far: -0.02%
# —————————next day—————————
# optimal slope: 0.4660400368489371
# beta_stock1: 1.4198368092272178
# beta_stock2: 1.7346369936199384
# position_XOM: -1.7346369936199384
# times_ret1： 0.04114520477596617
# position_CVX: 1.4198368092272178
# times_ret2： 0.02576882530790625
# ===========
# day 2021-08-20 00:00:00
#
# old_signal: -1.7412139203902073 →signal: -1.7346369936199384
# buy XOM: 0.006576926770268887 * 52.7400016784668  and sell CVX: 0.015616180592334494 * 94.30000305175781
# long position on XOM and short position on CVX
# gross daily return: -3.48%
# net daily return: -3.48%
# cumulative net return so far: -3.48%
# —————————next day—————————
# optimal slope: 0.8770915308311789
# beta_stock1: 1.534833061261044
# beta_stock2: 1.8442917265756662
# position_XOM: -1.8442917265756662
# times_ret1： 0.008195242472954778
# position_CVX: 1.534833061261044
# times_ret2： 0.01147516739828025
# ===========
# day 2021-08-23 00:00:00
#
# old_signal: -1.7346369936199384 →signal: -1.8442917265756662
# buy CVX: 0.11499625203382613 * 54.90999984741211  and sell XOM: 0.10965473295572781 * 54.90999984741211
# long position on CVX and short position on XOM
# gross daily return: 0.25%
# net daily return: 0.25%
# cumulative net return so far: 0.25%
# —————————next day—————————
# optimal slope: 1.1005234345103199
# beta_stock1: 1.9108771374463878
# beta_stock2: 1.9669186448590168
# position_XOM: -1.9669186448590168
# times_ret1： 0.0018063307987463695
# position_CVX: 1.9108771374463878
# times_ret2： 0.006847974483011887
# ===========
# day 2021-08-24 00:00:00
#
# old_signal: -1.8442917265756662 →signal: -1.9669186448590168
# buy CVX: 0.37604407618534386 * 55.36000061035156  and sell XOM: 0.1226269182833506 * 55.36000061035156
# long position on CVX and short position on XOM
# gross daily return: 0.95%
# net daily return: 0.95%
# cumulative net return so far: 0.95%
# —————————next day—————————
# optimal slope: 1.2396053379593432
# beta_stock1: 1.947993775366427
# beta_stock2: 2.087533120219191
# position_XOM: -2.087533120219191
# times_ret1： -0.013523260230452805
# position_CVX: 1.947993775366427
# times_ret2： -0.013095126256757017
# ===========
# day 2021-08-25 00:00:00
#
# old_signal: -1.9669186448590168 →signal: -2.087533120219191
# buy CVX: 0.037116637920039164 * 55.459999084472656  and sell XOM: 0.12061447536017433 * 55.459999084472656
# long position on CVX and short position on XOM
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: 0.27%
# —————————next day—————————
# optimal slope: 1.3245675486079918
# beta_stock1: 1.9799051379398456
# beta_stock2: 2.1244465886670967
# position_XOM: -2.1244465886670967
# times_ret1： 0.019374911186790023
# position_CVX: 1.9799051379398456
# times_ret2： 0.014606029120712627
# ===========
# day 2021-08-26 00:00:00
#
# old_signal: -2.087533120219191 →signal: -2.1244465886670967
# buy CVX: 0.031911362573418645 * 54.709999084472656  and sell XOM: 0.03691346844790555 * 54.709999084472656
# long position on CVX and short position on XOM
# gross daily return: -1.22%
# net daily return: -1.22%
# cumulative net return so far: -1.22%
# —————————next day—————————
# optimal slope: 1.423921093617901
# beta_stock1: 1.8913458620707624
# beta_stock2: 2.0323145157389764
# position_XOM: -2.0323145157389764
# times_ret1： -0.010937791022855303
# position_CVX: 1.8913458620707624
# times_ret2： -0.0025344687910271446
# ===========
# day 2021-08-27 00:00:00
#
# old_signal: -2.1244465886670967 →signal: -2.0323145157389764
# buy XOM: 0.09213207292812031 * 55.77000045776367  and sell CVX: 0.08855927586908319 * 98.63999938964844
# long position on XOM and short position on CVX
# gross daily return: 1.74%
# net daily return: 1.74%
# cumulative net return so far: 1.74%
# —————————next day—————————
# optimal slope: 1.5136681285442
# beta_stock1: 1.889222221231448
# beta_stock2: 2.13156716626758
# position_XOM: 0.0
# times_ret1： -0.011602599554366488
# position_CVX: -0.0
# times_ret2： -0.016465115932834062
# ===========
# day 2021-08-30 00:00:00
#
# old_signal: -2.0323145157389764 →signal: 0.0
# buy XOM: 2.0323145157389764 * 55.15999984741211  and sell CVX: 1.8913458620707624 * 98.38999938964844
# long position on XOM and short position on CVX
# gross daily return: 0.0%
# net daily return: -0.04%
# cumulative net return so far: -0.04%
# —————————next day—————————
# optimal slope: 1.5114384853962841
# beta_stock1: 1.8633823166085373
# beta_stock2: 2.1365580549519834
# position_XOM: 0.0
# times_ret1： -0.013756419547006793
# position_CVX: -0.0
# times_ret2： -0.010953783149373453
# ===========
# day 2021-08-31 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.5565919225866272
# beta_stock1: 1.8727421266058304
# beta_stock2: 2.2173895621476545
# position_XOM: 0.0
# times_ret1： 0.024363053043304772
# position_CVX: -0.0
# times_ret2： 0.02089645825024844
# ===========
# day 2021-09-01 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.603966583511385
# beta_stock1: 1.7698229192821706
# beta_stock2: 2.1414555802013173
# position_XOM: 0.0
# times_ret1： -0.0038126886744495048
# position_CVX: -0.0
# times_ret2： -0.0022515732551888767
# ===========
# day 2021-09-02 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.6604526962337969
# beta_stock1: 1.845620593507264
# beta_stock2: 2.194121805396671
# position_XOM: 0.0
# times_ret1： -0.0058319610179228265
# position_CVX: -0.0
# times_ret2： -0.0044107120176231085
# ===========
# day 2021-09-03 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.6970237989266663
# beta_stock1: 1.8265244119812487
# beta_stock2: 2.174811039160211
# position_XOM: 0.0
# times_ret1： -0.009165902969624717
# position_CVX: -0.0
# times_ret2： -0.00690292793939995
# ===========
# day 2021-09-07 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.7757524552635475
# beta_stock1: 1.7589198700376052
# beta_stock2: 2.062869015572594
# position_XOM: 0.0
# times_ret1： 0.0007400724531354541
# position_CVX: -0.0
# times_ret2： -0.004046056563107747
# ===========
# day 2021-09-08 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 1.913658520075201
# beta_stock1: 1.7655552413749223
# beta_stock2: 2.0593656531268616
# position_XOM: 0.0
# times_ret1： -0.002033658902592883
# position_CVX: -0.0
# times_ret2： 0.0007291634877522046
# ===========
# day 2021-09-09 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.1632253045208154
# beta_stock1: 1.6119011833552515
# beta_stock2: 1.9416962538903808
# position_XOM: 0.0
# times_ret1： 0.025750266792070597
# position_CVX: -0.0
# times_ret2： 0.01977726170411631
# ===========
# day 2021-09-10 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 2.561221749949391
# beta_stock1: 1.5430434095288736
# beta_stock2: 1.6978328996665608
# position_XOM: 0.0
# times_ret1： -0.014267601879529024
# position_CVX: -0.0
# times_ret2： -0.018066798513899585
# ===========
# day 2021-09-13 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 3.419352245319085
# beta_stock1: 1.6709916473544637
# beta_stock2: 1.7919718462004313
# position_XOM: 0.0
# times_ret1： 0.033711914183991665
# position_CVX: -0.0
# times_ret2： 0.02120583139545129
# ===========
# day 2021-09-14 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 8.48059680141186
# beta_stock1: 1.7953987881351712
# beta_stock2: 1.9135555495379992
# position_XOM: -1.9135555495379992
# times_ret1： -0.010634500063690933
# position_CVX: 1.7953987881351712
# times_ret2： -0.009364802411957363
# ===========
# day 2021-09-15 00:00:00
#
# old_signal: 0.0 →signal: -1.9135555495379992
# buy CVX: 1.7953987881351712 * 56.41999816894531  and sell XOM: 1.9135555495379992 * 56.41999816894531
# long position on CVX and short position on XOM
# gross daily return: 0.35%
# net daily return: 0.32%
# cumulative net return so far: 0.32%
# —————————next day—————————
# optimal slope: -0.26199387453166884
# beta_stock1: 2.117678403872862
# beta_stock2: 2.164541706876636
# position_XOM: 0.0
# times_ret1： -0.011823716428169484
# position_CVX: -0.0
# times_ret2： -0.005754187837544111
# ===========
# day 2021-09-16 00:00:00
#
# old_signal: -1.9135555495379992 →signal: 0.0
# buy XOM: 1.9135555495379992 * 55.81999969482422  and sell CVX: 1.7953987881351712 * 97.31999969482422
# long position on XOM and short position on CVX
# gross daily return: 0.0%
# net daily return: -0.04%
# cumulative net return so far: -0.04%
# —————————next day—————————
# optimal slope: 0.49088560006347215
# beta_stock1: 2.194026988115661
# beta_stock2: 1.7928850084508574
# position_XOM: 0.0
# times_ret1： -0.026649768396837525
# position_CVX: -0.0
# times_ret2： -0.020463035481808944
# ===========
# day 2021-09-17 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: 0.3214908781455468
# beta_stock1: 2.1036107236735173
# beta_stock2: 1.6396414061402564
# position_XOM: 0.0
# times_ret1： -0.0009312579314478819
# position_CVX: -0.0
# times_ret2： 0.0007385492269018634
# ===========
# day 2021-09-20 00:00:00
#
# old_signal: 0.0 →signal: 0.0
# no trading
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: 0.0%
# —————————next day—————————
# optimal slope: -2.3021656943846764
# beta_stock1: 2.1595257438269178
# beta_stock2: 1.6602823746439628
# position_XOM: -1.6602823746439628
# times_ret1： 0.02926919673170625
# position_CVX: 2.1595257438269178
# times_ret2： 0.02941487570280321
# ===========
# day 2021-09-21 00:00:00
#
# old_signal: 0.0 →signal: -1.6602823746439628
# buy CVX: 2.1595257438269178 * 53.63999938964844  and sell XOM: 1.6602823746439628 * 53.63999938964844
# long position on CVX and short position on XOM
# gross daily return: 1.49%
# net daily return: 1.45%
# cumulative net return so far: 1.45%
# —————————next day—————————
# optimal slope: 5.118427882535432
# beta_stock1: 1.8955735769415694
# beta_stock2: 1.5280808451548495
# position_XOM: -1.5280808451548495
# times_ret1： 0.0338707259118205
# position_CVX: 1.8955735769415694
# times_ret2： 0.02478490561319968
# ===========
# day 2021-09-22 00:00:00
#
# old_signal: -1.6602823746439628 →signal: -1.5280808451548495
# buy XOM: 0.13220152948911323 * 55.209999084472656  and sell CVX: 0.2639521668853484 * 97.63999938964844
# long position on XOM and short position on CVX
# gross daily return: -0.48%
# net daily return: -0.48%
# cumulative net return so far: -0.48%
# —————————next day—————————
# optimal slope: 7.03158930135559
# beta_stock1: 2.0025642772523513
# beta_stock2: 1.673213134543773
# position_XOM: -1.673213134543773
# times_ret1： 0.008934798619010031
# position_CVX: 2.0025642772523513
# times_ret2： 0.005396771224295938
# ===========
# day 2021-09-23 00:00:00
#
# old_signal: -1.5280808451548495 →signal: -1.673213134543773
# buy CVX: 0.10699070031078195 * 57.08000183105469  and sell XOM: 0.14513228938892353 * 57.08000183105469
# long position on CVX and short position on XOM
# gross daily return: -0.41%
# net daily return: -0.42%
# cumulative net return so far: -0.42%
# —————————next day—————————
# optimal slope: -2.1215168464966223
# beta_stock1: 2.1064800213337787
# beta_stock2: 1.7026086614714857
# position_XOM: 1.7026086614714857
# times_ret1： 0.02969263899881791
# position_CVX: -2.1064800213337787
# times_ret2： 0.023558675770673165
# ===========
# day 2021-09-24 00:00:00
#
# old_signal: -1.673213134543773 →signal: 1.7026086614714857
# buy XOM: 3.375821796015259 * 57.59000015258789  and sell CVX: 4.10904429858613 * 100.5999984741211
# long position on XOM and short position on CVX
# gross daily return: 0.09%
# net daily return: 0.02%
# cumulative net return so far: 0.02%
# —————————next day—————————

# %%
#visualising the results
plt.plot(np.append(1,np.cumprod(1+gross_returns)),label='gross returns')
plt.plot(np.append(1,np.cumprod(1+net_returns)),label='net returns')
plt.plot(np.append(1,np.cumprod(1+market_returns)),label='market')
plt.legend()

# %%
raw_data.loc[traded_dates]
# Out:
#                   XOM         CVX       market
# Date
# 2019-10-29  68.440002  118.129997  3036.889893
# 2019-10-30  67.720001  116.360001  3046.770020
# 2019-10-31  67.570000  116.139999  3037.560059
# 2019-11-01  69.599998  116.209999  3066.909912
# 2019-11-04  71.669998  121.570000  3078.270020
# ...               ...         ...          ...
# 2021-09-16  55.820000   97.320000  4473.750000
# 2021-09-21  53.639999   94.849998  4354.189941
# 2021-09-22  55.209999   97.639999  4395.640137
# 2021-09-23  57.080002  100.059998  4448.979980
# 2021-09-24  57.590000  100.599998  4455.479980
#
# [481 rows x 3 columns]

# %%
#building the output dataframe
output = pd.DataFrame()
#output['DF'] = DF_stats
output['KPSS'] = KPSS_stats
output['signal'] = signals
output['gross'] = gross_returns
output['net'] = net_returns
output['market'] = market_returns

# %%
''' KPSS_max= 0.463, fee=0.0001, entry=0.02, stop_loss= -0.05
signal = np.sign( CVX - fair_val(XOM) )
position0 = beta_stk2 * signal
position1 = beta_stk1 * -signal
gross = position0* (XOM_ret) + position1* (CVX_ret)
'''
output.set_index(raw_data[21:-1].index)#traded_dates)
# Out:
#                 KPSS  signal     gross       net    market
# Date
# 2019-10-29  0.076902     1.0  0.007012  0.006762  0.003253
# 2019-10-30  0.055737     1.0 -0.000139 -0.000151 -0.003023
# 2019-10-31  0.095836     1.0  0.024708  0.024675  0.009662
# 2019-11-01  0.124835    -1.0  0.028176  0.027773  0.003704
# 2019-11-04  0.067337    -1.0 -0.012596 -0.012616 -0.001186
# ...              ...     ...       ...       ...       ...
# 2021-09-20  0.150360     0.0 -0.000000 -0.000000 -0.000812
# 2021-09-21  0.066362    -1.0  0.014927  0.014545  0.009520
# 2021-09-22  0.117177    -1.0 -0.004776 -0.004815  0.012135
# 2021-09-23  0.104602    -1.0 -0.004142 -0.004168  0.001461
# 2021-09-24  0.087983     1.0  0.000929  0.000181 -0.002776
#
# [481 rows x 5 columns]

# %%
plt.plot(output['market'],label='market')
plt.plot(output['net'],label='net')
plt.plot(output['KPSS'],label='KPSS')
plt.legend()

# %%
plt.plot(output['market'],label='market')
plt.plot(output['net'],label='net')
#plt.plot(output['KPSS'],label='KPSS')
plt.legend()

# %% [markdown]
# ## *Statistical Tests*

# %%
window = 21
t = 22
data = raw_data[t-window:t]
data
# Out:
#                   XOM         CVX       market
# Date
# 2019-10-01  68.949997  116.010002  2940.250000
# 2019-10-02  67.150002  112.290001  2887.610107
# 2019-10-03  67.980003  113.150002  2910.629883
# 2019-10-04  68.970001  113.849998  2952.010010
# 2019-10-07  68.019997  113.260002  2938.790039
# 2019-10-08  66.699997  111.709999  2893.060059
# 2019-10-09  67.440002  113.139999  2919.399902
# 2019-10-10  68.250000  114.589996  2938.129883
# 2019-10-11  68.980003  116.150002  2970.270020
# 2019-10-14  69.180000  116.180000  2966.149902
# 2019-10-15  69.419998  116.309998  2995.679932
# 2019-10-16  68.230003  115.110001  2989.689941
# 2019-10-17  68.139999  115.349998  2997.949951
# 2019-10-18  67.610001  114.739998  2986.199951
# 2019-10-21  68.739998  116.610001  3006.719971
# 2019-10-22  69.089996  117.800003  2995.989990
# 2019-10-23  69.750000  117.980003  3004.520020
# 2019-10-24  69.089996  117.580002  3010.290039
# 2019-10-25  69.250000  118.669998  3022.550049
# 2019-10-28  68.639999  118.480003  3039.419922
# 2019-10-29  68.440002  118.129997  3036.889893

# %% [markdown]
# #### $I(1)$ Trail - optimal DF-stat for repective sequences (1-lag difference staionary)

# %%
def unit_root(b):
    a = np.average(np.array(data[stock1][:-1]) - b*np.array(data[stock1][:-1]))
    yhat_t = a + b*data[stock1][:-1]
    ts = np.array(yhat_t - data[stock1][:-1])
    ts_diff = ts[1:] - ts[:-1] #ts.diff(periods=1).dropna()
    reg = sm.OLS(ts_diff, ts[:-1]) #
    res = reg.fit()
    #a0 = res.params[0]
    #b0 = res.params[1] ###
    return res.params[0]/res.bse[0]

res1 = spop.minimize(unit_root, data[stock1][-1]/data[stock1][-2], method='Nelder-Mead') # b = stk1/stk2 <1
DF_opt = res1.fun #
b_opt = float(res1.x)
#a_opt = np.average(data[stock1][1:] - b_opt*data[stock1][:-1])

DF_opt, b_opt, a_opt
# Out:
# (-2.6558594442666923, 1.0212344751434461, -46.761817838075466)

# %% [markdown]
# -> stock 2 = a + b* stock 1 + ɛ

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import grangercausalitytests

for t in range(window, len(raw_data)-1):

  data = raw_data[t-window:t]

  stock2_ADF = adfuller(data[stock2])
  if
  print('P value for the Augmented Dickey-Fuller Test is', stock2_ADF[1])
  stock1_ADF = adfuller(data[stock1])
  print('P value for the Augmented Dickey-Fuller Test is', stock1_ADF[1])
  stock2_1_ADF = adfuller(data[stock2], maxlag = 1)
  print('P value for the Augmented Dickey-Fuller Test is', stock2_1_ADF[1])
  stock1_1_ADF = adfuller(data[stock1], maxlag = 1)
  print('P value for the Augmented Dickey-Fuller Test is', stock1_1_ADF[1])
  spread_ADF = adfuller(data[stock2] - data[stock1]) ###
  print('P value for the Augmented Dickey-Fuller Test is', spread_ADF[1])
  Ratio_ADF = adfuller(data[stock1] / data[stock2])
  print('P value for the Augmented Dickey-Fuller Test is', Ratio_ADF[1])

# %% [markdown]
# #### Granger Causality Test (if both series are stationary $I(1)$)

# %%
from statsmodels.tsa.stattools import grangercausalitytests
gc_df = pd.concat([data[stock2],data[stock1]],1) # stock2 granger caused by stock1, using stationary
gc_res = grangercausalitytests(gc_df,3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.8414  , p=0.0419  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=5.6958  , p=0.0170  , df=1
# likelihood ratio test: chi2=5.0119  , p=0.0252  , df=1
# parameter F test:         F=4.8414  , p=0.0419  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.1578  , p=0.0121  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=16.7141 , p=0.0002  , df=2
# likelihood ratio test: chi2=11.9910 , p=0.0025  , df=2
# parameter F test:         F=6.1578  , p=0.0121  , df_denom=14, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.6904  , p=0.0241  , df_denom=11, df_num=3
# ssr based chi2 test:   chi2=23.0257 , p=0.0000  , df=3
# likelihood ratio test: chi2=14.8289 , p=0.0020  , df=3
# parameter F test:         F=4.6904  , p=0.0241  , df_denom=11, df_num=3
# <ipython-input-24-077e28b74bcf>:2: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   gc_df = pd.concat([data[stock2],data[stock1]],1) # 1st column granger caused by 2nd

# %%
from statsmodels.tsa.stattools import grangercausalitytests
gc_df = pd.concat([data[stock1],data[stock2]],1) # 1st column granger caused by 2nd
gc_res = grangercausalitytests(gc_df,3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6181  , p=0.2205  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=1.9037  , p=0.1677  , df=1
# likelihood ratio test: chi2=1.8184  , p=0.1775  , df=1
# parameter F test:         F=1.6181  , p=0.2205  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8846  , p=0.0893  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=7.8296  , p=0.0199  , df=2
# likelihood ratio test: chi2=6.5562  , p=0.0377  , df=2
# parameter F test:         F=2.8846  , p=0.0893  , df_denom=14, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.9293  , p=0.0811  , df_denom=11, df_num=3
# ssr based chi2 test:   chi2=14.3801 , p=0.0024  , df=3
# likelihood ratio test: chi2=10.5691 , p=0.0143  , df=3
# parameter F test:         F=2.9293  , p=0.0811  , df_denom=11, df_num=3
# <ipython-input-25-1fc296d6ddc3>:2: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   gc_df = pd.concat([data[stock1],data[stock2]],1) # 1st column granger caused by 2nd

# %% [markdown]
# $Stock_2 = a + b* Stock_1$

# %% [markdown]
# #### cointgration unit test (if both series are non-stionary)

# %%
from statsmodels.tsa.stattools import adfuller
data = raw_data[22-21:22]
reg = sm.OLS(np.array(data[stock2]), sm.add_constant(np.array(data[stock1])))
res = reg.fit()
a0 = res.params[0]
b0 = res.params[1] ###

adfuller(res.resid,1)
# Out:
# (-0.7108101207222032,
#  0.8439295675234719,
#  0,
#  20,
#  {'1%': -3.8092091249999998, '5%': -3.0216450000000004, '10%': -2.6507125},
#  50.21533978494474)

# %%
import statsmodels.tsa.stattools as ts
ts.coint(data[stock2],data[stock1]),ts.coint(data[stock1],data[stock2]),ts.coint(data[stock2],data[stock1],'ct'),ts.coint(data[stock1],data[stock2],'ct')
# Out:
# ((0.1403048744047897,
#   0.9886785122195779,
#   array([-4.5278525, -3.6586925, -3.26331  ])),
#  (-1.406545716386021,
#   0.7952607466030888,
#   array([-4.5278525, -3.6586925, -3.26331  ])),
#  (-4.2077856628601635,
#   0.014700930165389516,
#   array([-5.1887525, -4.286285 , -3.8664935])),
#  (-1.0730567209798116,
#   0.9729773364221848,
#   array([-5.1887525, -4.286285 , -3.8664935])))

# %% [markdown]
# #### DeTrenidng by difference

# %%
from statsmodels.tsa.stattools import kpss
data = raw_data[22-21:22]
#data_diff = data.diff(periods=1).dropna()
#kpss(data[stock2]/data[stock1])[0]<kpss(data[stock2]/data[stock1])[-1]['2.5%'],kpss(data[stock2]/data[stock1]),kpss(data[stock1] / data[stock2]),kpss(data[stock2]/data[stock1],'ct'),kpss(data[stock1]/data[stock2],'ct')
kpss(data[stock2]),kpss(data[stock1])
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# ((0.6431534328690818,
#   0.018713324284628928,
#   2,
#   {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}),
#  (0.34086033190457454,
#   0.1,
#   1,
#   {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}))

# %%
from statsmodels.tsa.stattools import adfuller
data = raw_data[22-21:22]
#data_diff = data.diff(periods=1).dropna()
adfuller(data[stock2],maxlag = 1), adfuller(data[stock1],maxlag = 1)#,adfuller(data[stock1].diff(periods=1).dropna(),0)
#adfuller(data[stock2]/data[stock1],1),adfuller(data[stock1] / data[stock2],1)
#adfuller(data[stock2]/data[stock1],1,'ct'),adfuller(data[stock1] / data[stock2],1,'ct')
# Out:
# ((-0.4708125694294739,
#   0.8975874825637651,
#   5,
#   15,
#   {'1%': -3.9644434814814815,
#    '5%': -3.0849081481481484,
#    '10%': -2.6818144444444445},
#   27.551347277979634),
#  (-3.026393795317774,
#   0.03250199369678011,
#   1,
#   19,
#   {'1%': -3.8326031418574136,
#    '5%': -3.0312271701414204,
#    '10%': -2.655519584487535},
#   39.96433304340092))

# %%
DF_threshold = -2.567 # DF-critical: 10% = -1.161, 5% = -1.941, 1% = -2.567

for t in range(window, len(raw_data)-1):

  data = raw_data[t-window:t]

  #adfuller(data[stock2],maxlag = 1), adfuller(data[stock1],maxlag = 1)

  def coin_unit_root(b):
      a = np.average(data[stock2] - b*data[stock1]) #np.average(data[stock1][t-window:t] - b*data[stock2][t-window:t])
      fair_value = a + b*data[stock2]
      diff = np.array(data[stock1] - fair_value)
      diff_diff = diff[1:] - diff[:-1] #(df).diff(periods=1).dropna()
      reg = sm.OLS(diff_diff, diff[:-1]) #sm.add_constant(diff[:-1]))
      res = reg.fit()
      #a0 = res.params[0]
      #b0 = res.params[1] ###
      return res.params[0]/res.bse[0]

  res1 = spop.minimize(coin_unit_root, data[stock1][t]/data[stock2][t], method='Nelder-Mead') # b = stk1/stk2 <1
  DF_opt = res1.fun #
  b_opt = float(res1.x)
  a_opt = np.average(data[stock1] - b_opt*data[stock2])
  #simulating trading
  fair_value = a_opt + b_opt*data[stock2][t]

  #
  if DF_opt > DF_threshold:
      signal = 0
  else: #
      signal = np.sign(fair_value - data[stock2][t])

  position0 = signal
  position1 = -signal
  gross = position0*(raw_data[stock1][t+1]/raw_data[stock1][t] - 1) + position1*(raw_data[stock2][t+1]/raw_data[stock2][t] - 1)
  #gross_return = signal*returns[stock2][t] - signal*returns[stock1][t]

  DF_stats = np.append(DF_stats, DF_opt)
  gross_returns = np.append(gross_returns, gross)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-d461afb5cd39> in <cell line: 5>()
#      18       return res.params[0]/res.bse[0]
#      19
# ---> 20   res1 = spop.minimize(unit_root, data[stock1][t]/data[stock2][t], method='Nelder-Mead') # b = stk1/stk2 <1
#      21   DF_opt = res1.fun #
#      22   b_opt = float(res1.x)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     976
#     977         if is_integer(key) and self.index._should_fallback_to_positional:
# --> 978             return self._values[key]
#     979
#     980         elif key_is_scalar:
#
# IndexError: index 21 is out of bounds for axis 0 with size 21
